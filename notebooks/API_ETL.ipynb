# %%
# import package to make HTTP request fetch url similar to browser request
import requests
# import json library to decode json
import json
# import for data manipulation and analysis
import pandas as pd
# for key
from google.colab import userdata
# for time
import datetime
# for database connection
from sqlalchemy import create_engine
# !pip install mysqlclient
# Out:
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 842.9 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp310-cp310-linux_x86_64.whl size=124730 sha256=9f98760e446c62e4948b5950a1d582e065ce23290c0c1472b8434a48f01471d1
#   Stored in directory: /root/.cache/pip/wheels/ac/96/ac/2a4d8cb58a4d95de1dffc3f8b0ea42e0e5b63ab97640edbda3
# Successfully built mysqlclient
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.4

# %% [markdown]
# # Getting individual player stats per game using Rapid API

# %%
#https://rapidapi.com/api-sports/api/api-nba (player stats per game id)
url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

# Utah Jazz id = 40, selecting season as 2023
querystring = {"team":"40","season":"2023"}

# adding headers for authentication
api_key = userdata.get('RAPID_API_KEY_PLAYER_STATS')

headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

# incorporating variables into response
response = requests.get(url, headers=headers, params=querystring)

# printing response
print(response.json())
# Out:
# {'get': 'players/statistics', 'parameters': {'team': '40', 'season': '2023'}, 'errors': [], 'results': 966, 'response': [{'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 5, 'pos': 'PF', 'min': '18', 'fgm': 2, 'fga': 3, 'fgp': '66.7', 'ftm': 0, 'fta': 0, 'ftp': '0', 'tpm': 1, 'tpa': 1, 'tpp': '100.0', 'offReb': 1, 'defReb': 3, 'totReb': 4, 'assists': 0, 'pFouls': 0, 'steals': 0, 'turnovers': 2, 'blocks': 0, 'plusMinus': '-2', 'comment': None}, {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 10, 'pos': 'PF', 'min': '18', 'fgm': 4, 'fga': 10, 'fgp': '40.0', 'ftm': 2, 'fta': 2, 'ftp': '100.0', 'tpm': 0, 'tpa': 3, 'tpp': '0', 'offReb': 4, 'defReb': 4, 'totReb': 8, 'assists': 2, 'pFouls': 0, 'steals': 0, 'turnovers': 3, 'blocks': 0, 'plusMinus': '-4', 'comment': None}, {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 7, 'pos': 'C', 'min': '24', 'fgm': 3, 'fga': 5, 'fgp': '60.0', 'ftm': 1, 'fta': 3, 'ftp': '33.3', 'tpm': 0, 'tpa': 0, 'tpp': '0', 'offReb': 3, 'defReb': 4, 'totReb': 7, 'assists': 1, 'pFouls': 0, 'steals': 0, 'turnovers': 2, 'blocks': 5, 'plusMinus': '-5', 'comment': None}, {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 3, 'pos': 'PG', 'min': '18', 'fgm': 1, 'fga': 6, 'fgp': '16.7', 'ftm': 1, 'fta': 2, 'ftp': '50.0', 'tpm': 0, 'tpa': 2, 'tpp': '0', 'offReb': 1, 'defReb': 0, 'totReb': 1, 'assists': 5, 'pFouls': 1, 'steals': 0, 'turnovers': 4, 'blocks': 0, 'plusMinus': '-4', 'comment': None}, {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 13, 'pos': 'SG', 'min': '21', 'fgm': 5, 'fga': 13, 'fgp': '38.5', 'ftm': 0, 'fta': 0, 'ftp': '0', 'tpm': 3, 'tpa': 7, 'tpp': '42.9', 'offReb': 1, 'defReb': 5, 'totReb': 6, 'assists': 1, 'pFouls': 4, 'steals': 0, 'turnovers': 1, 'blocks': 0, 'plusMinus': '-7', 'comment': None}, {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 1, 'pos': 'PF', 'min': '21', 'fgm': 0, 'fga': 0, 'fgp': '0', 'ftm': 1, 'fta': 2, 'ftp': '50.0', 'tpm': 0, 'tpa': 0, 'tpp': '0', 'offReb': 1, 'defReb': 6, 'totReb': 7, 'assists': 2, 'pFouls': 4, 'steals': 0, 'turnovers': 2, 'blocks': 1, 'plusMinus': '+2', 'comment': None}, {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'}, 'team': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'game': {'id': 12485}, 'points': 6, 'pos': 'F', 'min': '12', 'fgm': 2, 'fga': 7, 'fgp': '28.6', 'ftm': 0, 'fta': 0, 'ftp': '0', 'tpm': 2, 'tpa': 5, 'tpp': '40.0', 'offReb': 1, 'defReb': 0, 'totReb': 1, 'assists': 1, 'pFouls': 1, 'steals': 0, 'turnovers': 0, 'blocks': 0, 'plusMinus': '+5', 'comment': None}, {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'}, 'team': {'id': 40, 'name': ' ...

# %%
# checking response code
response
# Out:
# <Response [200]>

# %%
# getting the text of the response
response.text
# Out:
# '{"get":"players\\/statistics","parameters":{"team":"40","season":"2023"},"errors":[],"results":966,"response":[{"player":{"id":761,"firstname":"John","lastname":"Collins"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":5,"pos":"PF","min":"18","fgm":2,"fga":3,"fgp":"66.7","ftm":0,"fta":0,"ftp":"0","tpm":1,"tpa":1,"tpp":"100.0","offReb":1,"defReb":3,"totReb":4,"assists":0,"pFouls":0,"steals":0,"turnovers":2,"blocks":0,"plusMinus":"-2","comment":null},{"player":{"id":830,"firstname":"Lauri","lastname":"Markkanen"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":10,"pos":"PF","min":"18","fgm":4,"fga":10,"fgp":"40.0","ftm":2,"fta":2,"ftp":"100.0","tpm":0,"tpa":3,"tpp":"0","offReb":4,"defReb":4,"totReb":8,"assists":2,"pFouls":0,"steals":0,"turnovers":3,"blocks":0,"plusMinus":"-4","comment":null},{"player":{"id":3457,"firstname":"Walker","lastname":"Kessler"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":7,"pos":"C","min":"24","fgm":3,"fga":5,"fgp":"60.0","ftm":1,"fta":3,"ftp":"33.3","tpm":0,"tpa":0,"tpp":"0","offReb":3,"defReb":4,"totReb":7,"assists":1,"pFouls":0,"steals":0,"turnovers":2,"blocks":5,"plusMinus":"-5","comment":null},{"player":{"id":1021,"firstname":"Collin","lastname":"Sexton"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":3,"pos":"PG","min":"18","fgm":1,"fga":6,"fgp":"16.7","ftm":1,"fta":2,"ftp":"50.0","tpm":0,"tpa":2,"tpp":"0","offReb":1,"defReb":0,"totReb":1,"assists":5,"pFouls":1,"steals":0,"turnovers":4,"blocks":0,"plusMinus":"-4","comment":null},{"player":{"id":1867,"firstname":"Talen","lastname":"Horton-Tucker"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":13,"pos":"SG","min":"21","fgm":5,"fga":13,"fgp":"38.5","ftm":0,"fta":0,"ftp":"0","tpm":3,"tpa":7,"tpp":"42.9","offReb":1,"defReb":5,"totReb":6,"assists":1,"pFouls":4,"steals":0,"turnovers":1,"blocks":0,"plusMinus":"-7","comment":null},{"player":{"id":404,"firstname":"Kelly","lastname":"Olynyk"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":1,"pos":"PF","min":"21","fgm":0,"fga":0,"fgp":"0","ftm":1,"fta":2,"ftp":"50.0","tpm":0,"tpa":0,"tpp":"0","offReb":1,"defReb":6,"totReb":7,"assists":2,"pFouls":4,"steals":0,"turnovers":2,"blocks":1,"plusMinus":"+2","comment":null},{"player":{"id":3438,"firstname":"Simone","lastname":"Fontecchio"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":6,"pos":"F","min":"12","fgm":2,"fga":7,"fgp":"28.6","ftm":0,"fta":0,"ftp":"0","tpm":2,"tpa":5,"tpp":"40.0","offReb":1,"defReb":0,"totReb":1,"assists":1,"pFouls":1,"steals":0,"turnovers":0,"blocks":0,"plusMinus":"+5","comment":null},{"player":{"id":1891,"firstname":"Luka","lastname":"Samanic"},"team":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"game":{"id":12485},"points":9,"pos":"F","min":"5","fgm":3,"fga":4,"fgp":"75.0","ftm":1,"fta":2,"ftp":"50.0","tpm":2,"tpa":2,"tpp":"100.0","offReb":0,"defReb":0,"totReb":0,"assists":0,"pFouls":1,"steals":0,"turnovers":0,"blocks":0,"plusMi ...

# %%
# viewing the text response in json format
json.loads(response.text)
# Out:
# {'get': 'players/statistics',
#  'parameters': {'team': '40', 'season': '2023'},
#  'errors': [],
#  'results': 966,
#  'response': [{'player': {'id': 761,
#     'firstname': 'John',
#     'lastname': 'Collins'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 5,
#    'pos': 'PF',
#    'min': '18',
#    'fgm': 2,
#    'fga': 3,
#    'fgp': '66.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 0,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 10,
#    'pos': 'PF',
#    'min': '18',
#    'fgm': 4,
#    'fga': 10,
#    'fgp': '40.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 3,
#    'tpp': '0',
#    'offReb': 4,
#    'defReb': 4,
#    'totReb': 8,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 7,
#    'pos': 'C',
#    'min': '24',
#    'fgm': 3,
#    'fga': 5,
#    'fgp': '60.0',
#    'ftm': 1,
#    'fta': 3,
#    'ftp': '33.3',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 3,
#    'defReb': 4,
#    'totReb': 7,
#    'assists': 1,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 5,
#    'plusMinus': '-5',
#    'comment': None},
#   {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 3,
#    'pos': 'PG',
#    'min': '18',
#    'fgm': 1,
#    'fga': 6,
#    'fgp': '16.7',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 0,
#    'totReb': 1,
#    'assists': 5,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 4,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 13,
#    'pos': 'SG',
#    'min': '21',
#    'fgm': 5,
#    'fga': 13,
#    'fgp': '38.5',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 3,
#    'tpa': 7,
#    'tpp': '42.9',
#    'offReb': 1,
#    'defReb': 5,
#    'totReb': 6,
#    'assists': 1,
#    'pFouls': 4,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-7',
#    'comment': None},
#   {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 1,
#    'pos': 'PF',
#    'min': '21',
#    'fgm': 0,
#    'fga': 0,
#    'fgp': '0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 6,
#    'totReb': 7,
#    'assists': 2,
#    'pFouls': 4,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '+2',
#    'comment': None},
#   {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 6,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 2,
#    'fga': 7,
#    'fgp': '28.6',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 5,
#    'tpp': '40.0',
#    'offReb': 1,
#    'defReb': 0,
#    'totReb': 1,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+5',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 9,
#    'pos': 'F',
#    'min': '5',
#    'fgm': 3,
#    'fga': 4,
#    'fgp': '75.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 2,
#    'tpa': 2,
#    'tpp': '100.0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-3',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 3,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 1,
#    'fga': 3,
#    'fgp': '33.3',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+2',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 4,
#    'pos': 'C',
#    'min': '16',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 0,
#    'fta': 1,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 3,
#    'defReb': 3,
#    'totReb': 6,
#    'assists': 0,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 6,
#    'pos': 'PG',
#    'min': '14',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 15,
#    'pos': 'G',
#    'min': '16',
#    'fgm': 7,
#    'fga': 7,
#    'fgp': '100.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 5,
#    'pFouls': 0,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 9,
#    'pos': 'G',
#    'min': '19',
#    'fgm': 4,
#    'fga': 10,
#    'fgp': '40.0',
#    'ftm': 1,
#    'fta': 1,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 4,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12485},
#    'points': 10,
#    'pos': 'G',
#    'min': '25',
#    'fgm': 2,
#    'fga': 9,
#    'fgp': '22.2',
#    'ftm': 5,
#    'fta': 6,
#    'ftp': '83.3',
#    'tpm': 1,
#    'tpa': 6,
#    'tpp': '16.7',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 5,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 3,
#    'blocks': 1,
#    'plusMinus': '+15',
#    'comment': None},
#   {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 3,
#    'pos': 'PF',
#    'min': '19',
#    'fgm': 1,
#    'fga': 6,
#    'fgp': '16.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 0,
#    'pFouls': 3,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '-13',
#    'comment': None},
#   {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 16,
#    'pos': 'PF',
#    'min': '23',
#    'fgm': 6,
#    'fga': 12,
#    'fgp': '50.0',
#    'ftm': 3,
#    'fta': 3,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 5,
#    'tpp': '20.0',
#    'offReb': 1,
#    'defReb': 7,
#    'totReb': 8,
#    'assists': 0,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '-16',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 3,
#    'pos': 'C',
#    'min': '17',
#    'fgm': 1,
#    'fga': 2,
#    'fgp': '50.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 4,
#    'totReb': 4,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-8',
#    'comment': None},
#   {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 5,
#    'pos': 'PG',
#    'min': '18',
#    'fgm': 1,
#    'fga': 5,
#    'fgp': '20.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 2,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 0,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-14',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 24,
#    'pos': 'SG',
#    'min': '25',
#    'fgm': 9,
#    'fga': 18,
#    'fgp': '50.0',
#    'ftm': 4,
#    'fta': 5,
#    'ftp': '80.0',
#    'tpm': 2,
#    'tpa': 7,
#    'tpp': '28.6',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 7,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 8,
#    'pos': 'PF',
#    'min': '20',
#    'fgm': 3,
#    'fga': 5,
#    'fgp': '60.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 4,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 7,
#    'pos': 'F',
#    'min': '15',
#    'fgm': 2,
#    'fga': 6,
#    'fgp': '33.3',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 4,
#    'tpp': '25.0',
#    'offReb': 2,
#    'defReb': 3,
#    'totReb': 5,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 0,
#    'pos': 'F',
#    'min': '9',
#    'fgm': 0,
#    'fga': 7,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 3,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+2',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 0,
#    'pos': 'F',
#    'min': '5',
#    'fgm': 0,
#    'fga': 1,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 0,
#    'totReb': 1,
#    'assists': 0,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+1',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 2,
#    'pos': 'C',
#    'min': '10',
#    'fgm': 1,
#    'fga': 1,
#    'fgp': '100.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '+7',
#    'comment': None},
#   {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 12,
#    'pos': 'PG',
#    'min': '20',
#    'fgm': 5,
#    'fga': 12,
#    'fgp': '41.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 5,
#    'tpp': '40.0',
#    'offReb': 0,
#    'defReb': 5,
#    'totReb': 5,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 4,
#    'blocks': 1,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 4,
#    'pos': 'G',
#    'min': '19',
#    'fgm': 2,
#    'fga': 3,
#    'fgp': '66.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 1,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 4,
#    'pos': 'G',
#    'min': '17',
#    'fgm': 2,
#    'fga': 5,
#    'fgp': '40.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 2,
#    'defReb': 1,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+11',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12495},
#    'points': 10,
#    'pos': 'G',
#    'min': '22',
#    'fgm': 3,
#    'fga': 7,
#    'fgp': '42.9',
#    'ftm': 3,
#    'fta': 4,
#    'ftp': '75.0',
#    'tpm': 1,
#    'tpa': 4,
#    'tpp': '25.0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 5,
#    'pFouls': 0,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+5',
#    'comment': None},
#   {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 15,
#    'pos': 'PF',
#    'min': '24',
#    'fgm': 5,
#    'fga': 7,
#    'fgp': '71.4',
#    'ftm': 4,
#    'fta': 4,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 26,
#    'pos': 'PF',
#    'min': '25',
#    'fgm': 9,
#    'fga': 12,
#    'fgp': '75.0',
#    'ftm': 6,
#    'fta': 6,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 2,
#    'tpp': '100.0',
#    'offReb': 3,
#    'defReb': 6,
#    'totReb': 9,
#    'assists': 1,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+14',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 8,
#    'pos': 'C',
#    'min': '21',
#    'fgm': 4,
#    'fga': 9,
#    'fgp': '44.4',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 4,
#    'totReb': 4,
#    'assists': 2,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 2,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 9,
#    'pos': 'PG',
#    'min': '25',
#    'fgm': 4,
#    'fga': 7,
#    'fgp': '57.1',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 6,
#    'pFouls': 1,
#    'steals': 2,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '+14',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 8,
#    'pos': 'SG',
#    'min': '17',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 3,
#    'fta': 4,
#    'ftp': '75.0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 6,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 5,
#    'pos': 'PF',
#    'min': '15',
#    'fgm': 1,
#    'fga': 2,
#    'fgp': '50.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+4',
#    'comment': None},
#   {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 4,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 1,
#    'fga': 5,
#    'fgp': '20.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 2,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 2,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 1,
#    'fga': 2,
#    'fgp': '50.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 7,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 1,
#    'fga': 3,
#    'fgp': '33.3',
#    'ftm': 4,
#    'fta': 4,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 2,
#    'tpp': '50.0',
#    'offReb': 1,
#    'defReb': 0,
#    'totReb': 1,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 3,
#    'pos': 'C',
#    'min': '12',
#    'fgm': 1,
#    'fga': 1,
#    'fgp': '100.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 4,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 16,
#    'pos': 'PG',
#    'min': '19',
#    'fgm': 3,
#    'fga': 7,
#    'fgp': '42.9',
#    'ftm': 8,
#    'fta': 8,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 3,
#    'tpp': '66.7',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 6,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '+6',
#    'comment': None},
#   {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 9,
#    'pos': 'G',
#    'min': '11',
#    'fgm': 4,
#    'fga': 4,
#    'fgp': '100.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 9,
#    'pos': 'G',
#    'min': '12',
#    'fgm': 2,
#    'fga': 3,
#    'fgp': '66.7',
#    'ftm': 4,
#    'fta': 6,
#    'ftp': '66.7',
#    'tpm': 1,
#    'tpa': 2,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 1,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+6',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12512},
#    'points': 17,
#    'pos': 'G',
#    'min': '23',
#    'fgm': 4,
#    'fga': 8,
#    'fgp': '50.0',
#    'ftm': 6,
#    'fta': 6,
#    'ftp': '100.0',
#    'tpm': 3,
#    'tpa': 6,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 9,
#    'pos': 'PF',
#    'min': '17',
#    'fgm': 4,
#    'fga': 5,
#    'fgp': '80.0',
#    'ftm': 1,
#    'fta': 1,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 1,
#    'pFouls': 3,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+6',
#    'comment': None},
#   {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 15,
#    'pos': 'PF',
#    'min': '17',
#    'fgm': 5,
#    'fga': 12,
#    'fgp': '41.7',
#    'ftm': 4,
#    'fta': 5,
#    'ftp': '80.0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 3,
#    'defReb': 4,
#    'totReb': 7,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 8,
#    'pos': 'C',
#    'min': '11',
#    'fgm': 3,
#    'fga': 5,
#    'fgp': '60.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 1,
#    'defReb': 1,
#    'totReb': 2,
#    'assists': 1,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 3,
#    'plusMinus': '+9',
#    'comment': None},
#   {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 12,
#    'pos': 'PG',
#    'min': '17',
#    'fgm': 4,
#    'fga': 7,
#    'fgp': '57.1',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 4,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 0,
#    'pos': 'SG',
#    'min': '13',
#    'fgm': 0,
#    'fga': 3,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 0,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '+7',
#    'comment': None},
#   {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 0,
#    'pos': 'PF',
#    'min': '13',
#    'fgm': 0,
#    'fga': 2,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 2,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+5',
#    'comment': None},
#   {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 0,
#    'pos': 'F',
#    'min': '7',
#    'fgm': 0,
#    'fga': 0,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+4',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 2,
#    'pos': 'F',
#    'min': '8',
#    'fgm': 1,
#    'fga': 1,
#    'fgp': '100.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 2,
#    'defReb': 1,
#    'totReb': 3,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-1',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 4,
#    'pos': 'F',
#    'min': '16',
#    'fgm': 2,
#    'fga': 3,
#    'fgp': '66.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 3,
#    'totReb': 4,
#    'assists': 1,
#    'pFouls': 4,
#    'steals': 1,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+5',
#    'comment': None},
#   {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 6,
#    'pos': 'F',
#    'min': '17',
#    'fgm': 3,
#    'fga': 8,
#    'fgp': '37.5',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 1,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 7,
#    'pos': 'C',
#    'min': '9',
#    'fgm': 3,
#    'fga': 4,
#    'fgp': '75.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+4',
#    'comment': None},
#   {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 8,
#    'pos': 'C',
#    'min': '15',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 4,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 8,
#    'pos': 'PG',
#    'min': '11',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 4,
#    'fta': 4,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 2,
#    'totReb': 2,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+9',
#    'comment': None},
#   {'player': {'id': 1874, 'firstname': 'Romeo', 'lastname': 'Langford'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 4,
#    'pos': 'SG',
#    'min': '7',
#    'fgm': 2,
#    'fga': 3,
#    'fgp': '66.7',
#    'ftm': 0,
#    'fta': 2,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-1',
#    'comment': None},
#   {'player': {'id': 2799, 'firstname': 'Josh', 'lastname': 'Christopher'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 4,
#    'pos': 'SG',
#    'min': '8',
#    'fgm': 2,
#    'fga': 4,
#    'fgp': '50.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+1',
#    'comment': None},
#   {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 0,
#    'pos': 'G',
#    'min': '7',
#    'fgm': 0,
#    'fga': 0,
#    'fgp': '0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 3,
#    'pFouls': 2,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 12,
#    'pos': 'G',
#    'min': '16',
#    'fgm': 4,
#    'fga': 8,
#    'fgp': '50.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 5,
#    'tpp': '40.0',
#    'offReb': 0,
#    'defReb': 4,
#    'totReb': 4,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 2,
#    'plusMinus': '+14',
#    'comment': None},
#   {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 7,
#    'pos': 'G',
#    'min': '15',
#    'fgm': 3,
#    'fga': 4,
#    'fgp': '75.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 1,
#    'tpp': '100.0',
#    'offReb': 0,
#    'defReb': 3,
#    'totReb': 3,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12523},
#    'points': 8,
#    'pos': 'G',
#    'min': '16',
#    'fgm': 3,
#    'fga': 7,
#    'fgp': '42.9',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+12',
#    'comment': None},
#   {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 11,
#    'pos': 'F',
#    'min': '27',
#    'fgm': 3,
#    'fga': 7,
#    'fgp': '42.9',
#    'ftm': 3,
#    'fta': 3,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 6,
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 5,
#    'totReb': 5,
#    'assists': 2,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+20',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 14,
#    'pos': 'C',
#    'min': '32',
#    'fgm': 7,
#    'fga': 12,
#    'fgp': '58.3',
#    'ftm': 0,
#    'fta': 2,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 5,
#    'defReb': 10,
#    'totReb': 15,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+22',
#    'comment': None},
#   {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 24,
#    'pos': 'PG',
#    'min': '25',
#    'fgm': 11,
#    'fga': 16,
#    'fgp': '68.8',
#    'ftm': 0,
#    'fta': 1,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 3,
#    'tpp': '66.7',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 5,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+22',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 26,
#    'pos': 'SG',
#    'min': '31',
#    'fgm': 10,
#    'fga': 19,
#    'fgp': '52.6',
#    'ftm': 4,
#    'fta': 5,
#    'ftp': '80.0',
#    'tpm': 2,
#    'tpa': 6,
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 5,
#    'totReb': 5,
#    'assists': 8,
#    'pFouls': 0,
#    'steals': 2,
#    'turnovers': 4,
#    'blocks': 0,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 8,
#    'pos': 'G',
#    'min': '33',
#    'fgm': 3,
#    'fga': 8,
#    'fgp': '37.5',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 1,
#    'tpa': 5,
#    'tpp': '20.0',
#    'offReb': 2,
#    'defReb': 3,
#    'totReb': 5,
#    'assists': 1,
#    'pFouls': 3,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 3,
#    'pos': 'F',
#    'min': '12',
#    'fgm': 1,
#    'fga': 3,
#    'fgp': '33.3',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 1,
#    'totReb': 2,
#    'assists': 1,
#    'pFouls': 0,
#    'steals': 1,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '-19',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 5,
#    'pos': 'F',
#    'min': '15',
#    'fgm': 2,
#    'fga': 9,
#    'fgp': '22.2',
#    'ftm': 0,
#    'fta': 1,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 6,
#    'tpp': '16.7',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-14',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 3,
#    'pos': 'C',
#    'min': '16',
#    'fgm': 1,
#    'fga': 5,
#    'fgp': '20.0',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 3,
#    'defReb': 3,
#    'totReb': 6,
#    'assists': 0,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-25',
#    'comment': None},
#   {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 12,
#    'pos': 'G',
#    'min': '23',
#    'fgm': 5,
#    'fga': 7,
#    'fgp': '71.4',
#    'ftm': 2,
#    'fta': 5,
#    'ftp': '40.0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 2,
#    'defReb': 3,
#    'totReb': 5,
#    'assists': 5,
#    'pFouls': 5,
#    'steals': 3,
#    'turnovers': 4,
#    'blocks': 0,
#    'plusMinus': '-15',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12540},
#    'points': 7,
#    'pos': 'G',
#    'min': '26',
#    'fgm': 2,
#    'fga': 12,
#    'fgp': '16.7',
#    'ftm': 2,
#    'fta': 4,
#    'ftp': '50.0',
#    'tpm': 1,
#    'tpa': 6,
#    'tpp': '16.7',
#    'offReb': 1,
#    'defReb': 0,
#    'totReb': 1,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '-24',
#    'comment': None},
#   {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12560},
#    'points': 15,
#    'pos': 'PF',
#    'min': '31',
#    'fgm': 6,
#    'fga': 11,
#    'fgp': '54.5',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 3,
#    'defReb': 8,
#    'totReb': 11,
#    'assists': 2,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12560},
#    'points': 19,
#    'pos': 'PF',
#    'min': '32',
#    'fgm': 6,
#    'fga': 15,
#    'fgp': '40.0',
#    'ftm': 5,
#    'fta': 6,
#    'ftp': '83.3',
#    'tpm': 2,
#    'tpa': 6,
#    'tpp': '33.3',
#    'offReb': 2,
#    'defReb': 8,
#    'totReb': 10,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-7',
#    'comment': None},
#   {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12560},
#    'points': 8,
#    'pos': 'C',
#    'min': '22',
#    'fgm': 4,
#    'fga': 5,
#    'fgp': '80.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 4,
#    'defReb': 4,
#    'totReb': 8,
#    'assists': 0,
#    'pFouls': 3,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '-14',
#    'comment': None},
#   {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12560},
#    'points': 24,
#    'pos': 'PG',
#    'min': '31',
#    'fgm': 8,
#    'fga': 16,
#    'fgp': '50.0',
#    'ftm': 6,
#    'fta': 8,
#    'ftp': '75.0',
#    'tpm': 2,
#    'tpa': 5,
#    'tpp': '40.0',
#    'offReb': 2,
#    'defReb': 2,
#    'totReb': 4,
#    'assists': 6,
#    'pFouls': 4,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 12560},
#    'points': 8,
#    'pos': 'SG',
#    'min': '22',
#    'fgm': 3,
#    'fga': 9,
#    'fgp': '33.3',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 4,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 1,
# ...
#    'tpp': '33.3',
#    'offReb': 0,
#    'defReb': 4,
#    'totReb': 4,
#    'assists': 5,
#    'pFouls': 3,
#    'steals': 2,
#    'turnovers': 5,
#    'blocks': 0,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13716},
#    'points': 8,
#    'pos': 'F',
#    'min': '23',
#    'fgm': 4,
#    'fga': 5,
#    'fgp': '80.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 2,
#    'defReb': 5,
#    'totReb': 7,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 2,
#    'plusMinus': '-1',
#    'comment': None},
#   {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13716},
#    'points': 14,
#    'pos': 'F',
#    'min': '27',
#    'fgm': 5,
#    'fga': 7,
#    'fgp': '71.4',
#    'ftm': 2,
#    'fta': 4,
#    'ftp': '50.0',
#    'tpm': 2,
#    'tpa': 3,
#    'tpp': '66.7',
#    'offReb': 5,
#    'defReb': 4,
#    'totReb': 9,
#    'assists': 5,
#    'pFouls': 3,
#    'steals': 2,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '+5',
#    'comment': None},
#   {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13716},
#    'points': 17,
#    'pos': 'F',
#    'min': '24',
#    'fgm': 5,
#    'fga': 12,
#    'fgp': '41.7',
#    'ftm': 3,
#    'fta': 3,
#    'ftp': '100.0',
#    'tpm': 4,
#    'tpa': 9,
#    'tpp': '44.4',
#    'offReb': 1,
#    'defReb': 5,
#    'totReb': 6,
#    'assists': 3,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+4',
#    'comment': None},
#   {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13716},
#    'points': 2,
#    'pos': 'C',
#    'min': '8',
#    'fgm': 1,
#    'fga': 2,
#    'fgp': '50.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-5',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13716},
#    'points': 16,
#    'pos': 'SG',
#    'min': '29',
#    'fgm': 5,
#    'fga': 13,
#    'fgp': '38.5',
#    'ftm': 4,
#    'fta': 4,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 6,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 5,
#    'pFouls': 5,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 2,
#    'plusMinus': '+6',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 11,
#    'pos': 'F',
#    'min': '28',
#    'fgm': 4,
#    'fga': 9,
#    'fgp': '44.4',
#    'ftm': 3,
#    'fta': 5,
#    'ftp': '60.0',
#    'tpm': 0,
#    'tpa': 3,
#    'tpp': '0',
#    'offReb': 3,
#    'defReb': 3,
#    'totReb': 6,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 1,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 7,
#    'pos': 'F',
#    'min': '23',
#    'fgm': 3,
#    'fga': 5,
#    'fgp': '60.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 3,
#    'tpp': '33.3',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 1,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 4,
#    'pos': 'C',
#    'min': '13',
#    'fgm': 1,
#    'fga': 4,
#    'fgp': '25.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 9,
#    'totReb': 10,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '0',
#    'comment': None},
#   {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 12,
#    'pos': 'G',
#    'min': '23',
#    'fgm': 4,
#    'fga': 6,
#    'fgp': '66.7',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 3,
#    'tpp': '66.7',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 2,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+10',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 14,
#    'pos': 'G',
#    'min': '28',
#    'fgm': 5,
#    'fga': 15,
#    'fgp': '33.3',
#    'ftm': 2,
#    'fta': 3,
#    'ftp': '66.7',
#    'tpm': 2,
#    'tpa': 7,
#    'tpp': '28.6',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 2,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 5,
#    'blocks': 0,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 12,
#    'pos': 'F',
#    'min': '23',
#    'fgm': 5,
#    'fga': 7,
#    'fgp': '71.4',
#    'ftm': 1,
#    'fta': 1,
#    'ftp': '100.0',
#    'tpm': 1,
#    'tpa': 2,
#    'tpp': '50.0',
#    'offReb': 2,
#    'defReb': 3,
#    'totReb': 5,
#    'assists': 1,
#    'pFouls': 1,
#    'steals': 2,
#    'turnovers': 2,
#    'blocks': 1,
#    'plusMinus': '-1',
#    'comment': None},
#   {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 27,
#    'pos': 'F',
#    'min': '35',
#    'fgm': 10,
#    'fga': 16,
#    'fgp': '62.5',
#    'ftm': 7,
#    'fta': 7,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 5,
#    'tpp': '0',
#    'offReb': 4,
#    'defReb': 5,
#    'totReb': 9,
#    'assists': 8,
#    'pFouls': 5,
#    'steals': 1,
#    'turnovers': 3,
#    'blocks': 0,
#    'plusMinus': '+1',
#    'comment': None},
#   {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 9,
#    'pos': 'F',
#    'min': '21',
#    'fgm': 3,
#    'fga': 8,
#    'fgp': '37.5',
#    'ftm': 3,
#    'fta': 3,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 4,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 1,
#    'pFouls': 0,
#    'steals': 1,
#    'turnovers': 0,
#    'blocks': 2,
#    'plusMinus': '-6',
#    'comment': None},
#   {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 12,
#    'pos': 'SG',
#    'min': '29',
#    'fgm': 5,
#    'fga': 12,
#    'fgp': '41.7',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 5,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+1',
#    'comment': None},
#   {'player': {'id': 2842, 'firstname': 'Jason', 'lastname': 'Preston'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13732},
#    'points': 2,
#    'pos': 'G',
#    'min': '18',
#    'fgm': 1,
#    'fga': 6,
#    'fgp': '16.7',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 2,
#    'defReb': 4,
#    'totReb': 6,
#    'assists': 2,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '+8',
#    'comment': None},
#   {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 14,
#    'pos': 'F',
#    'min': '29',
#    'fgm': 5,
#    'fga': 11,
#    'fgp': '45.5',
#    'ftm': 4,
#    'fta': 4,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 5,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 4,
#    'totReb': 5,
#    'assists': 2,
#    'pFouls': 4,
#    'steals': 1,
#    'turnovers': 7,
#    'blocks': 0,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 16,
#    'pos': 'F',
#    'min': '41',
#    'fgm': 6,
#    'fga': 10,
#    'fgp': '60.0',
#    'ftm': 2,
#    'fta': 2,
#    'ftp': '100.0',
#    'tpm': 2,
#    'tpa': 4,
#    'tpp': '50.0',
#    'offReb': 3,
#    'defReb': 5,
#    'totReb': 8,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 3,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '+2',
#    'comment': None},
#   {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 11,
#    'pos': 'C',
#    'min': '30',
#    'fgm': 5,
#    'fga': 12,
#    'fgp': '41.7',
#    'ftm': 1,
#    'fta': 2,
#    'ftp': '50.0',
#    'tpm': 0,
#    'tpa': 1,
#    'tpp': '0',
#    'offReb': 6,
#    'defReb': 12,
#    'totReb': 18,
#    'assists': 2,
#    'pFouls': 2,
#    'steals': 0,
#    'turnovers': 2,
#    'blocks': 0,
#    'plusMinus': '+1',
#    'comment': None},
#   {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 8,
#    'pos': 'G',
#    'min': '19',
#    'fgm': 2,
#    'fga': 5,
#    'fgp': '40.0',
#    'ftm': 2,
#    'fta': 4,
#    'ftp': '50.0',
#    'tpm': 2,
#    'tpa': 4,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 2,
#    'pFouls': 0,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 0,
#    'plusMinus': '+13',
#    'comment': None},
#   {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 21,
#    'pos': 'G',
#    'min': '20',
#    'fgm': 8,
#    'fga': 11,
#    'fgp': '72.7',
#    'ftm': 0,
#    'fta': 1,
#    'ftp': '0',
#    'tpm': 5,
#    'tpa': 6,
#    'tpp': '83.3',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 4,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '+13',
#    'comment': None},
#   {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 2,
#    'pos': 'F',
#    'min': '7',
#    'fgm': 1,
#    'fga': 1,
#    'fgp': '100.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 0,
#    'tpa': 0,
#    'tpp': '0',
#    'offReb': 0,
#    'defReb': 0,
#    'totReb': 0,
#    'assists': 0,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 0,
#    'blocks': 1,
#    'plusMinus': '-9',
#    'comment': None},
#   {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 7,
#    'pos': 'F',
#    'min': '16',
#    'fgm': 3,
#    'fga': 5,
#    'fgp': '60.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 1,
#    'tpa': 2,
#    'tpp': '50.0',
#    'offReb': 0,
#    'defReb': 1,
#    'totReb': 1,
#    'assists': 6,
#    'pFouls': 1,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 1,
#    'plusMinus': '-4',
#    'comment': None},
#   {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 14,
#    'pos': 'F',
#    'min': '29',
#    'fgm': 6,
#    'fga': 15,
#    'fgp': '40.0',
#    'ftm': 0,
#    'fta': 0,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 7,
#    'tpp': '28.6',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 0,
#    'pFouls': 3,
#    'steals': 1,
#    'turnovers': 5,
#    'blocks': 0,
#    'plusMinus': '-20',
#    'comment': None},
#   {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 10,
#    'pos': 'C',
#    'min': '21',
#    'fgm': 4,
#    'fga': 7,
#    'fgp': '57.1',
#    'ftm': 0,
#    'fta': 2,
#    'ftp': '0',
#    'tpm': 2,
#    'tpa': 3,
#    'tpp': '66.7',
#    'offReb': 2,
#    'defReb': 6,
#    'totReb': 8,
#    'assists': 1,
#    'pFouls': 5,
#    'steals': 0,
#    'turnovers': 1,
#    'blocks': 2,
#    'plusMinus': '-2',
#    'comment': None},
#   {'player': {'id': 2611, 'firstname': 'Kira', 'lastname': 'Lewis Jr.'},
#    'team': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'game': {'id': 13746},
#    'points': 13,
#    'pos': 'PG',
#    'min': '28',
#    'fgm': 6,
#    'fga': 12,
#    'fgp': '50.0',
#    'ftm': 1,
#    'fta': 1,
#    'ftp': '100.0',
#    'tpm': 0,
#    'tpa': 2,
#    'tpp': '0',
#    'offReb': 1,
#    'defReb': 2,
#    'totReb': 3,
#    'assists': 3,
#    'pFouls': 1,
#    'steals': 1,
#    'turnovers': 1,
#    'blocks': 0,
#    'plusMinus': '-20',
#    'comment': None}]}

# %%
# assigning json output to variable
api_response = json.loads(response.text)

# %%
# getting type of the response
type(api_response)
# Out:
# dict

# %%
# accessing the response key since everything is under that key
api_response['response']
# Out:
# [{'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 5,
#   'pos': 'PF',
#   'min': '18',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 10,
#   'pos': 'PF',
#   'min': '18',
#   'fgm': 4,
#   'fga': 10,
#   'fgp': '40.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 3,
#   'tpp': '0',
#   'offReb': 4,
#   'defReb': 4,
#   'totReb': 8,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 7,
#   'pos': 'C',
#   'min': '24',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 1,
#   'fta': 3,
#   'ftp': '33.3',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 3,
#   'defReb': 4,
#   'totReb': 7,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 5,
#   'plusMinus': '-5',
#   'comment': None},
#  {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 3,
#   'pos': 'PG',
#   'min': '18',
#   'fgm': 1,
#   'fga': 6,
#   'fgp': '16.7',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 5,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 4,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 13,
#   'pos': 'SG',
#   'min': '21',
#   'fgm': 5,
#   'fga': 13,
#   'fgp': '38.5',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 3,
#   'tpa': 7,
#   'tpp': '42.9',
#   'offReb': 1,
#   'defReb': 5,
#   'totReb': 6,
#   'assists': 1,
#   'pFouls': 4,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-7',
#   'comment': None},
#  {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 1,
#   'pos': 'PF',
#   'min': '21',
#   'fgm': 0,
#   'fga': 0,
#   'fgp': '0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 6,
#   'totReb': 7,
#   'assists': 2,
#   'pFouls': 4,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 6,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 2,
#   'fga': 7,
#   'fgp': '28.6',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 5,
#   'tpp': '40.0',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+5',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 9,
#   'pos': 'F',
#   'min': '5',
#   'fgm': 3,
#   'fga': 4,
#   'fgp': '75.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 2,
#   'tpa': 2,
#   'tpp': '100.0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-3',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 3,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 1,
#   'fga': 3,
#   'fgp': '33.3',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 4,
#   'pos': 'C',
#   'min': '16',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 1,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 3,
#   'defReb': 3,
#   'totReb': 6,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 6,
#   'pos': 'PG',
#   'min': '14',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 15,
#   'pos': 'G',
#   'min': '16',
#   'fgm': 7,
#   'fga': 7,
#   'fgp': '100.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 5,
#   'pFouls': 0,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 9,
#   'pos': 'G',
#   'min': '19',
#   'fgm': 4,
#   'fga': 10,
#   'fgp': '40.0',
#   'ftm': 1,
#   'fta': 1,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 4,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12485},
#   'points': 10,
#   'pos': 'G',
#   'min': '25',
#   'fgm': 2,
#   'fga': 9,
#   'fgp': '22.2',
#   'ftm': 5,
#   'fta': 6,
#   'ftp': '83.3',
#   'tpm': 1,
#   'tpa': 6,
#   'tpp': '16.7',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 5,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 3,
#   'blocks': 1,
#   'plusMinus': '+15',
#   'comment': None},
#  {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 3,
#   'pos': 'PF',
#   'min': '19',
#   'fgm': 1,
#   'fga': 6,
#   'fgp': '16.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 0,
#   'pFouls': 3,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '-13',
#   'comment': None},
#  {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 16,
#   'pos': 'PF',
#   'min': '23',
#   'fgm': 6,
#   'fga': 12,
#   'fgp': '50.0',
#   'ftm': 3,
#   'fta': 3,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 5,
#   'tpp': '20.0',
#   'offReb': 1,
#   'defReb': 7,
#   'totReb': 8,
#   'assists': 0,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '-16',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 3,
#   'pos': 'C',
#   'min': '17',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 4,
#   'totReb': 4,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-8',
#   'comment': None},
#  {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 5,
#   'pos': 'PG',
#   'min': '18',
#   'fgm': 1,
#   'fga': 5,
#   'fgp': '20.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 2,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 0,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-14',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 24,
#   'pos': 'SG',
#   'min': '25',
#   'fgm': 9,
#   'fga': 18,
#   'fgp': '50.0',
#   'ftm': 4,
#   'fta': 5,
#   'ftp': '80.0',
#   'tpm': 2,
#   'tpa': 7,
#   'tpp': '28.6',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 7,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 8,
#   'pos': 'PF',
#   'min': '20',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 4,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 7,
#   'pos': 'F',
#   'min': '15',
#   'fgm': 2,
#   'fga': 6,
#   'fgp': '33.3',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 4,
#   'tpp': '25.0',
#   'offReb': 2,
#   'defReb': 3,
#   'totReb': 5,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 0,
#   'pos': 'F',
#   'min': '9',
#   'fgm': 0,
#   'fga': 7,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 3,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 0,
#   'pos': 'F',
#   'min': '5',
#   'fgm': 0,
#   'fga': 1,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 0,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 2,
#   'pos': 'C',
#   'min': '10',
#   'fgm': 1,
#   'fga': 1,
#   'fgp': '100.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '+7',
#   'comment': None},
#  {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 12,
#   'pos': 'PG',
#   'min': '20',
#   'fgm': 5,
#   'fga': 12,
#   'fgp': '41.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 5,
#   'tpp': '40.0',
#   'offReb': 0,
#   'defReb': 5,
#   'totReb': 5,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 4,
#   'blocks': 1,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 4,
#   'pos': 'G',
#   'min': '19',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 1,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 4,
#   'pos': 'G',
#   'min': '17',
#   'fgm': 2,
#   'fga': 5,
#   'fgp': '40.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 2,
#   'defReb': 1,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+11',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12495},
#   'points': 10,
#   'pos': 'G',
#   'min': '22',
#   'fgm': 3,
#   'fga': 7,
#   'fgp': '42.9',
#   'ftm': 3,
#   'fta': 4,
#   'ftp': '75.0',
#   'tpm': 1,
#   'tpa': 4,
#   'tpp': '25.0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 5,
#   'pFouls': 0,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+5',
#   'comment': None},
#  {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 15,
#   'pos': 'PF',
#   'min': '24',
#   'fgm': 5,
#   'fga': 7,
#   'fgp': '71.4',
#   'ftm': 4,
#   'fta': 4,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 26,
#   'pos': 'PF',
#   'min': '25',
#   'fgm': 9,
#   'fga': 12,
#   'fgp': '75.0',
#   'ftm': 6,
#   'fta': 6,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 2,
#   'tpp': '100.0',
#   'offReb': 3,
#   'defReb': 6,
#   'totReb': 9,
#   'assists': 1,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+14',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 8,
#   'pos': 'C',
#   'min': '21',
#   'fgm': 4,
#   'fga': 9,
#   'fgp': '44.4',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 4,
#   'totReb': 4,
#   'assists': 2,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 2,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 9,
#   'pos': 'PG',
#   'min': '25',
#   'fgm': 4,
#   'fga': 7,
#   'fgp': '57.1',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 6,
#   'pFouls': 1,
#   'steals': 2,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '+14',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 8,
#   'pos': 'SG',
#   'min': '17',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 3,
#   'fta': 4,
#   'ftp': '75.0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 6,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 5,
#   'pos': 'PF',
#   'min': '15',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+4',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 4,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 1,
#   'fga': 5,
#   'fgp': '20.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 2,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 2,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 7,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 1,
#   'fga': 3,
#   'fgp': '33.3',
#   'ftm': 4,
#   'fta': 4,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 2,
#   'tpp': '50.0',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 3,
#   'pos': 'C',
#   'min': '12',
#   'fgm': 1,
#   'fga': 1,
#   'fgp': '100.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 4,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 16,
#   'pos': 'PG',
#   'min': '19',
#   'fgm': 3,
#   'fga': 7,
#   'fgp': '42.9',
#   'ftm': 8,
#   'fta': 8,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 6,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '+6',
#   'comment': None},
#  {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 9,
#   'pos': 'G',
#   'min': '11',
#   'fgm': 4,
#   'fga': 4,
#   'fgp': '100.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 9,
#   'pos': 'G',
#   'min': '12',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 4,
#   'fta': 6,
#   'ftp': '66.7',
#   'tpm': 1,
#   'tpa': 2,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+6',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12512},
#   'points': 17,
#   'pos': 'G',
#   'min': '23',
#   'fgm': 4,
#   'fga': 8,
#   'fgp': '50.0',
#   'ftm': 6,
#   'fta': 6,
#   'ftp': '100.0',
#   'tpm': 3,
#   'tpa': 6,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 9,
#   'pos': 'PF',
#   'min': '17',
#   'fgm': 4,
#   'fga': 5,
#   'fgp': '80.0',
#   'ftm': 1,
#   'fta': 1,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 1,
#   'pFouls': 3,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+6',
#   'comment': None},
#  {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 15,
#   'pos': 'PF',
#   'min': '17',
#   'fgm': 5,
#   'fga': 12,
#   'fgp': '41.7',
#   'ftm': 4,
#   'fta': 5,
#   'ftp': '80.0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 3,
#   'defReb': 4,
#   'totReb': 7,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 8,
#   'pos': 'C',
#   'min': '11',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 1,
#   'defReb': 1,
#   'totReb': 2,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 3,
#   'plusMinus': '+9',
#   'comment': None},
#  {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 12,
#   'pos': 'PG',
#   'min': '17',
#   'fgm': 4,
#   'fga': 7,
#   'fgp': '57.1',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 4,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 0,
#   'pos': 'SG',
#   'min': '13',
#   'fgm': 0,
#   'fga': 3,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 0,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '+7',
#   'comment': None},
#  {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 0,
#   'pos': 'PF',
#   'min': '13',
#   'fgm': 0,
#   'fga': 2,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 2,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+5',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 0,
#   'pos': 'F',
#   'min': '7',
#   'fgm': 0,
#   'fga': 0,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+4',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 2,
#   'pos': 'F',
#   'min': '8',
#   'fgm': 1,
#   'fga': 1,
#   'fgp': '100.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 2,
#   'defReb': 1,
#   'totReb': 3,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-1',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 4,
#   'pos': 'F',
#   'min': '16',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 3,
#   'totReb': 4,
#   'assists': 1,
#   'pFouls': 4,
#   'steals': 1,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+5',
#   'comment': None},
#  {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 6,
#   'pos': 'F',
#   'min': '17',
#   'fgm': 3,
#   'fga': 8,
#   'fgp': '37.5',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 1,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 7,
#   'pos': 'C',
#   'min': '9',
#   'fgm': 3,
#   'fga': 4,
#   'fgp': '75.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+4',
#   'comment': None},
#  {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 8,
#   'pos': 'C',
#   'min': '15',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 4,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 8,
#   'pos': 'PG',
#   'min': '11',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 4,
#   'fta': 4,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+9',
#   'comment': None},
#  {'player': {'id': 1874, 'firstname': 'Romeo', 'lastname': 'Langford'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 4,
#   'pos': 'SG',
#   'min': '7',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 0,
#   'fta': 2,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-1',
#   'comment': None},
#  {'player': {'id': 2799, 'firstname': 'Josh', 'lastname': 'Christopher'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 4,
#   'pos': 'SG',
#   'min': '8',
#   'fgm': 2,
#   'fga': 4,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 0,
#   'pos': 'G',
#   'min': '7',
#   'fgm': 0,
#   'fga': 0,
#   'fgp': '0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 3,
#   'pFouls': 2,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 12,
#   'pos': 'G',
#   'min': '16',
#   'fgm': 4,
#   'fga': 8,
#   'fgp': '50.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 5,
#   'tpp': '40.0',
#   'offReb': 0,
#   'defReb': 4,
#   'totReb': 4,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 2,
#   'plusMinus': '+14',
#   'comment': None},
#  {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 7,
#   'pos': 'G',
#   'min': '15',
#   'fgm': 3,
#   'fga': 4,
#   'fgp': '75.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 1,
#   'tpp': '100.0',
#   'offReb': 0,
#   'defReb': 3,
#   'totReb': 3,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12523},
#   'points': 8,
#   'pos': 'G',
#   'min': '16',
#   'fgm': 3,
#   'fga': 7,
#   'fgp': '42.9',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+12',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 11,
#   'pos': 'F',
#   'min': '27',
#   'fgm': 3,
#   'fga': 7,
#   'fgp': '42.9',
#   'ftm': 3,
#   'fta': 3,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 6,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 5,
#   'totReb': 5,
#   'assists': 2,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+20',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 14,
#   'pos': 'C',
#   'min': '32',
#   'fgm': 7,
#   'fga': 12,
#   'fgp': '58.3',
#   'ftm': 0,
#   'fta': 2,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 5,
#   'defReb': 10,
#   'totReb': 15,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+22',
#   'comment': None},
#  {'player': {'id': 1021, 'firstname': 'Collin', 'lastname': 'Sexton'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 24,
#   'pos': 'PG',
#   'min': '25',
#   'fgm': 11,
#   'fga': 16,
#   'fgp': '68.8',
#   'ftm': 0,
#   'fta': 1,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 5,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+22',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 26,
#   'pos': 'SG',
#   'min': '31',
#   'fgm': 10,
#   'fga': 19,
#   'fgp': '52.6',
#   'ftm': 4,
#   'fta': 5,
#   'ftp': '80.0',
#   'tpm': 2,
#   'tpa': 6,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 5,
#   'totReb': 5,
#   'assists': 8,
#   'pFouls': 0,
#   'steals': 2,
#   'turnovers': 4,
#   'blocks': 0,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 3411, 'firstname': 'Ochai', 'lastname': 'Agbaji'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 8,
#   'pos': 'G',
#   'min': '33',
#   'fgm': 3,
#   'fga': 8,
#   'fgp': '37.5',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 1,
#   'tpa': 5,
#   'tpp': '20.0',
#   'offReb': 2,
#   'defReb': 3,
#   'totReb': 5,
#   'assists': 1,
#   'pFouls': 3,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 3,
#   'pos': 'F',
#   'min': '12',
#   'fgm': 1,
#   'fga': 3,
#   'fgp': '33.3',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 1,
#   'totReb': 2,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 1,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '-19',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 5,
#   'pos': 'F',
#   'min': '15',
#   'fgm': 2,
#   'fga': 9,
#   'fgp': '22.2',
#   'ftm': 0,
#   'fta': 1,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 6,
#   'tpp': '16.7',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-14',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 3,
#   'pos': 'C',
#   'min': '16',
#   'fgm': 1,
#   'fga': 5,
#   'fgp': '20.0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 3,
#   'defReb': 3,
#   'totReb': 6,
#   'assists': 0,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-25',
#   'comment': None},
#  {'player': {'id': 152, 'firstname': 'Kris', 'lastname': 'Dunn'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 12,
#   'pos': 'G',
#   'min': '23',
#   'fgm': 5,
#   'fga': 7,
#   'fgp': '71.4',
#   'ftm': 2,
#   'fta': 5,
#   'ftp': '40.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 2,
#   'defReb': 3,
#   'totReb': 5,
#   'assists': 5,
#   'pFouls': 5,
#   'steals': 3,
#   'turnovers': 4,
#   'blocks': 0,
#   'plusMinus': '-15',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12540},
#   'points': 7,
#   'pos': 'G',
#   'min': '26',
#   'fgm': 2,
#   'fga': 12,
#   'fgp': '16.7',
#   'ftm': 2,
#   'fta': 4,
#   'ftp': '50.0',
#   'tpm': 1,
#   'tpa': 6,
#   'tpp': '16.7',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '-24',
#   'comment': None},
#  {'player': {'id': 761, 'firstname': 'John', 'lastname': 'Collins'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 15,
#   'pos': 'PF',
#   'min': '31',
#   'fgm': 6,
#   'fga': 11,
#   'fgp': '54.5',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 3,
#   'defReb': 8,
#   'totReb': 11,
#   'assists': 2,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 830, 'firstname': 'Lauri', 'lastname': 'Markkanen'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 19,
#   'pos': 'PF',
#   'min': '32',
#   'fgm': 6,
#   'fga': 15,
#   'fgp': '40.0',
#   'ftm': 5,
#   'fta': 6,
#   'ftp': '83.3',
#   'tpm': 2,
#   'tpa': 6,
#   'tpp': '33.3',
#   'offReb': 2,
#   'defReb': 8,
#   'totReb': 10,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-7',
#   'comment': None},
#  {'player': {'id': 3457, 'firstname': 'Walker', 'lastname': 'Kessler'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 8,
#   'pos': 'C',
#   'min': '22',
#   'fgm': 4,
#   'fga': 5,
#   'fgp': '80.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 4,
#   'defReb': 4,
#   'totReb': 8,
#   'assists': 0,
#   'pFouls': 3,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '-14',
#   'comment': None},
#  {'player': {'id': 109, 'firstname': 'Jordan', 'lastname': 'Clarkson'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 24,
#   'pos': 'PG',
#   'min': '31',
#   'fgm': 8,
#   'fga': 16,
#   'fgp': '50.0',
#   'ftm': 6,
#   'fta': 8,
#   'ftp': '75.0',
#   'tpm': 2,
#   'tpa': 5,
#   'tpp': '40.0',
#   'offReb': 2,
#   'defReb': 2,
#   'totReb': 4,
#   'assists': 6,
#   'pFouls': 4,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 8,
#   'pos': 'SG',
#   'min': '22',
#   'fgm': 3,
#   'fga': 9,
#   'fgp': '33.3',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 4,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '-5',
#   'comment': None},
#  {'player': {'id': 404, 'firstname': 'Kelly', 'lastname': 'Olynyk'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 5,
#   'pos': 'PF',
#   'min': '17',
#   'fgm': 2,
#   'fga': 3,
#   'fgp': '66.7',
#   'ftm': 1,
#   'fta': 1,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 3,
#   'defReb': 3,
#   'totReb': 6,
#   'assists': 4,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-5',
#   'comment': None},
#  {'player': {'id': 3438, 'firstname': 'Simone', 'lastname': 'Fontecchio'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 2,
#   'pos': 'F',
#   'min': '2',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 0,
#   'totReb': 1,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 2,
#   'pos': 'F',
#   'min': '2',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 12560},
#   'points': 1,
#   'pos': 'F',
#   'min': '2',
#   'fgm': 0,
#   'fga': 0,
#   'fgp': '0',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 0,
# ...
#   'min': '24',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 0,
#   'defReb': 2,
#   'totReb': 2,
#   'assists': 1,
#   'pFouls': 3,
#   'steals': 0,
#   'turnovers': 3,
#   'blocks': 1,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 20,
#   'pos': 'G',
#   'min': '33',
#   'fgm': 7,
#   'fga': 14,
#   'fgp': '50.0',
#   'ftm': 4,
#   'fta': 5,
#   'ftp': '80.0',
#   'tpm': 2,
#   'tpa': 6,
#   'tpp': '33.3',
#   'offReb': 0,
#   'defReb': 4,
#   'totReb': 4,
#   'assists': 5,
#   'pFouls': 3,
#   'steals': 2,
#   'turnovers': 5,
#   'blocks': 0,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 8,
#   'pos': 'F',
#   'min': '23',
#   'fgm': 4,
#   'fga': 5,
#   'fgp': '80.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 2,
#   'defReb': 5,
#   'totReb': 7,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 2,
#   'plusMinus': '-1',
#   'comment': None},
#  {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 14,
#   'pos': 'F',
#   'min': '27',
#   'fgm': 5,
#   'fga': 7,
#   'fgp': '71.4',
#   'ftm': 2,
#   'fta': 4,
#   'ftp': '50.0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 5,
#   'defReb': 4,
#   'totReb': 9,
#   'assists': 5,
#   'pFouls': 3,
#   'steals': 2,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '+5',
#   'comment': None},
#  {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 17,
#   'pos': 'F',
#   'min': '24',
#   'fgm': 5,
#   'fga': 12,
#   'fgp': '41.7',
#   'ftm': 3,
#   'fta': 3,
#   'ftp': '100.0',
#   'tpm': 4,
#   'tpa': 9,
#   'tpp': '44.4',
#   'offReb': 1,
#   'defReb': 5,
#   'totReb': 6,
#   'assists': 3,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+4',
#   'comment': None},
#  {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 2,
#   'pos': 'C',
#   'min': '8',
#   'fgm': 1,
#   'fga': 2,
#   'fgp': '50.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-5',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13716},
#   'points': 16,
#   'pos': 'SG',
#   'min': '29',
#   'fgm': 5,
#   'fga': 13,
#   'fgp': '38.5',
#   'ftm': 4,
#   'fta': 4,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 6,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 5,
#   'pFouls': 5,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 2,
#   'plusMinus': '+6',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 11,
#   'pos': 'F',
#   'min': '28',
#   'fgm': 4,
#   'fga': 9,
#   'fgp': '44.4',
#   'ftm': 3,
#   'fta': 5,
#   'ftp': '60.0',
#   'tpm': 0,
#   'tpa': 3,
#   'tpp': '0',
#   'offReb': 3,
#   'defReb': 3,
#   'totReb': 6,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 1,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 7,
#   'pos': 'F',
#   'min': '23',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 3,
#   'tpp': '33.3',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 1,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 4,
#   'pos': 'C',
#   'min': '13',
#   'fgm': 1,
#   'fga': 4,
#   'fgp': '25.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 9,
#   'totReb': 10,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '0',
#   'comment': None},
#  {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 12,
#   'pos': 'G',
#   'min': '23',
#   'fgm': 4,
#   'fga': 6,
#   'fgp': '66.7',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 2,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+10',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 14,
#   'pos': 'G',
#   'min': '28',
#   'fgm': 5,
#   'fga': 15,
#   'fgp': '33.3',
#   'ftm': 2,
#   'fta': 3,
#   'ftp': '66.7',
#   'tpm': 2,
#   'tpa': 7,
#   'tpp': '28.6',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 2,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 5,
#   'blocks': 0,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 12,
#   'pos': 'F',
#   'min': '23',
#   'fgm': 5,
#   'fga': 7,
#   'fgp': '71.4',
#   'ftm': 1,
#   'fta': 1,
#   'ftp': '100.0',
#   'tpm': 1,
#   'tpa': 2,
#   'tpp': '50.0',
#   'offReb': 2,
#   'defReb': 3,
#   'totReb': 5,
#   'assists': 1,
#   'pFouls': 1,
#   'steals': 2,
#   'turnovers': 2,
#   'blocks': 1,
#   'plusMinus': '-1',
#   'comment': None},
#  {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 27,
#   'pos': 'F',
#   'min': '35',
#   'fgm': 10,
#   'fga': 16,
#   'fgp': '62.5',
#   'ftm': 7,
#   'fta': 7,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 5,
#   'tpp': '0',
#   'offReb': 4,
#   'defReb': 5,
#   'totReb': 9,
#   'assists': 8,
#   'pFouls': 5,
#   'steals': 1,
#   'turnovers': 3,
#   'blocks': 0,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 9,
#   'pos': 'F',
#   'min': '21',
#   'fgm': 3,
#   'fga': 8,
#   'fgp': '37.5',
#   'ftm': 3,
#   'fta': 3,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 4,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 1,
#   'pFouls': 0,
#   'steals': 1,
#   'turnovers': 0,
#   'blocks': 2,
#   'plusMinus': '-6',
#   'comment': None},
#  {'player': {'id': 1867, 'firstname': 'Talen', 'lastname': 'Horton-Tucker'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 12,
#   'pos': 'SG',
#   'min': '29',
#   'fgm': 5,
#   'fga': 12,
#   'fgp': '41.7',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 5,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 2842, 'firstname': 'Jason', 'lastname': 'Preston'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13732},
#   'points': 2,
#   'pos': 'G',
#   'min': '18',
#   'fgm': 1,
#   'fga': 6,
#   'fgp': '16.7',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 2,
#   'defReb': 4,
#   'totReb': 6,
#   'assists': 2,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '+8',
#   'comment': None},
#  {'player': {'id': 1891, 'firstname': 'Luka', 'lastname': 'Samanic'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 14,
#   'pos': 'F',
#   'min': '29',
#   'fgm': 5,
#   'fga': 11,
#   'fgp': '45.5',
#   'ftm': 4,
#   'fta': 4,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 5,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 4,
#   'totReb': 5,
#   'assists': 2,
#   'pFouls': 4,
#   'steals': 1,
#   'turnovers': 7,
#   'blocks': 0,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 4031, 'firstname': 'Taylor', 'lastname': 'Hendricks'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 16,
#   'pos': 'F',
#   'min': '41',
#   'fgm': 6,
#   'fga': 10,
#   'fgp': '60.0',
#   'ftm': 2,
#   'fta': 2,
#   'ftp': '100.0',
#   'tpm': 2,
#   'tpa': 4,
#   'tpp': '50.0',
#   'offReb': 3,
#   'defReb': 5,
#   'totReb': 8,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 3,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '+2',
#   'comment': None},
#  {'player': {'id': 2785, 'firstname': 'Omer', 'lastname': 'Yurtseven'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 11,
#   'pos': 'C',
#   'min': '30',
#   'fgm': 5,
#   'fga': 12,
#   'fgp': '41.7',
#   'ftm': 1,
#   'fta': 2,
#   'ftp': '50.0',
#   'tpm': 0,
#   'tpa': 1,
#   'tpp': '0',
#   'offReb': 6,
#   'defReb': 12,
#   'totReb': 18,
#   'assists': 2,
#   'pFouls': 2,
#   'steals': 0,
#   'turnovers': 2,
#   'blocks': 0,
#   'plusMinus': '+1',
#   'comment': None},
#  {'player': {'id': 3454, 'firstname': 'Johnny', 'lastname': 'Juzang'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 8,
#   'pos': 'G',
#   'min': '19',
#   'fgm': 2,
#   'fga': 5,
#   'fgp': '40.0',
#   'ftm': 2,
#   'fta': 4,
#   'ftp': '50.0',
#   'tpm': 2,
#   'tpa': 4,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 2,
#   'pFouls': 0,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'plusMinus': '+13',
#   'comment': None},
#  {'player': {'id': 4029, 'firstname': 'Keyonte', 'lastname': 'George'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 21,
#   'pos': 'G',
#   'min': '20',
#   'fgm': 8,
#   'fga': 11,
#   'fgp': '72.7',
#   'ftm': 0,
#   'fta': 1,
#   'ftp': '0',
#   'tpm': 5,
#   'tpa': 6,
#   'tpp': '83.3',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 4,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '+13',
#   'comment': None},
#  {'player': {'id': 1847, 'firstname': 'Darius', 'lastname': 'Bazley'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 2,
#   'pos': 'F',
#   'min': '7',
#   'fgm': 1,
#   'fga': 1,
#   'fgp': '100.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 0,
#   'tpa': 0,
#   'tpp': '0',
#   'offReb': 0,
#   'defReb': 0,
#   'totReb': 0,
#   'assists': 0,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 0,
#   'blocks': 1,
#   'plusMinus': '-9',
#   'comment': None},
#  {'player': {'id': 3463, 'firstname': 'Kenneth', 'lastname': 'Lofton Jr.'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 7,
#   'pos': 'F',
#   'min': '16',
#   'fgm': 3,
#   'fga': 5,
#   'fgp': '60.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 1,
#   'tpa': 2,
#   'tpp': '50.0',
#   'offReb': 0,
#   'defReb': 1,
#   'totReb': 1,
#   'assists': 6,
#   'pFouls': 1,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 1,
#   'plusMinus': '-4',
#   'comment': None},
#  {'player': {'id': 4034, 'firstname': 'Brice', 'lastname': 'Sensabaugh'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 14,
#   'pos': 'F',
#   'min': '29',
#   'fgm': 6,
#   'fga': 15,
#   'fgp': '40.0',
#   'ftm': 0,
#   'fta': 0,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 7,
#   'tpp': '28.6',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 0,
#   'pFouls': 3,
#   'steals': 1,
#   'turnovers': 5,
#   'blocks': 0,
#   'plusMinus': '-20',
#   'comment': None},
#  {'player': {'id': 3358, 'firstname': 'Micah', 'lastname': 'Potter'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 10,
#   'pos': 'C',
#   'min': '21',
#   'fgm': 4,
#   'fga': 7,
#   'fgp': '57.1',
#   'ftm': 0,
#   'fta': 2,
#   'ftp': '0',
#   'tpm': 2,
#   'tpa': 3,
#   'tpp': '66.7',
#   'offReb': 2,
#   'defReb': 6,
#   'totReb': 8,
#   'assists': 1,
#   'pFouls': 5,
#   'steals': 0,
#   'turnovers': 1,
#   'blocks': 2,
#   'plusMinus': '-2',
#   'comment': None},
#  {'player': {'id': 2611, 'firstname': 'Kira', 'lastname': 'Lewis Jr.'},
#   'team': {'id': 40,
#    'name': 'Utah Jazz',
#    'nickname': 'Jazz',
#    'code': 'UTA',
#    'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#   'game': {'id': 13746},
#   'points': 13,
#   'pos': 'PG',
#   'min': '28',
#   'fgm': 6,
#   'fga': 12,
#   'fgp': '50.0',
#   'ftm': 1,
#   'fta': 1,
#   'ftp': '100.0',
#   'tpm': 0,
#   'tpa': 2,
#   'tpp': '0',
#   'offReb': 1,
#   'defReb': 2,
#   'totReb': 3,
#   'assists': 3,
#   'pFouls': 1,
#   'steals': 1,
#   'turnovers': 1,
#   'blocks': 0,
#   'plusMinus': '-20',
#   'comment': None}]

# %%
# turning into variable
players = api_response['response']

# %%
# checking type of variable
type(players)
# Out:
# list

# %%
# creating empty dictionary
jazz_player_data_per_game = {
    'id': [],
    'firstname': [],
    'lastname': [],
    'game': [],
    'points': [],
    'min': [],
    'fgm': [],
    'fga': [],
    'fgp': [],
    'ftm': [],
    'fta': [],
    'ftp': [],
    'tpm': [],
    'tpa': [],
    'tpp': [],
    'totReb': [],
    'assists': [],
    'steals': [],
    'turnovers': [],
    'blocks': [],
    'plusMinus': [],
}

# looping through businesses and extracting business details
for player in players:
  id = player['player']['id']
  jazz_player_data_per_game['id'].append(id)
  print('id: ', id)

  firstname = player['player']['firstname']
  jazz_player_data_per_game['firstname'].append(firstname)
  print(firstname)

  lastname = player['player']['lastname']
  jazz_player_data_per_game['lastname'].append(lastname)
  print(lastname)

  game = player['game']['id']
  jazz_player_data_per_game['game'].append(game)
  print('game_id:', game)

  points = player['points']
  jazz_player_data_per_game['points'].append(points)
  print(points, 'points')

  min = player['min']
  jazz_player_data_per_game['min'].append(min)
  print(min, 'minutes')

  fgm = player['fgm']
  jazz_player_data_per_game['fgm'].append(fgm)
  print(fgm, 'field goals made')

  fga = player['fga']
  jazz_player_data_per_game['fga'].append(fga)
  print(fga, 'field goals attempted')

  fgp = player['fgp']
  jazz_player_data_per_game['fgp'].append(fgp)
  print(fgp, '%')

  ftm = player['ftm']
  jazz_player_data_per_game['ftm'].append(ftm)
  print(ftm, 'free throws made')

  fta = player['fta']
  jazz_player_data_per_game['fta'].append(fta)
  print(fta, 'free throws attempted')

  ftp = player['ftp']
  jazz_player_data_per_game['ftp'].append(ftp)
  print(ftp, '%')

  tpm = player['tpm']
  jazz_player_data_per_game['tpm'].append(tpm)
  print(tpm, 'three points made')

  tpa = player['tpa']
  jazz_player_data_per_game['tpa'].append(tpa)
  print(tpa, 'three points attempted')

  tpp = player['tpp']
  jazz_player_data_per_game['tpp'].append(tpp)
  print(tpp, '%')

  totReb = player['totReb']
  jazz_player_data_per_game['totReb'].append(totReb)
  print(totReb, 'rebounds')

  assists = player['assists']
  jazz_player_data_per_game['assists'].append(assists)
  print(assists, 'assists')

  steals = player['steals']
  jazz_player_data_per_game['steals'].append(steals)
  print(steals, 'steals')

  turnovers = player['turnovers']
  jazz_player_data_per_game['turnovers'].append(turnovers)
  print(turnovers, 'turmnovers')

  blocks = player['blocks']
  jazz_player_data_per_game['blocks'].append(blocks)
  print(blocks, 'blocks')

  plusMinus = player['plusMinus']
  jazz_player_data_per_game['plusMinus'].append(plusMinus)
  print(plusMinus, 'plus/minus')

  print('-' * 75)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# +2 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13415
# 7 points
# 15 minutes
# 3 field goals made
# 4 field goals attempted
# 75.0 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 5 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +10 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13415
# 7 points
# 20 minutes
# 1 field goals made
# 7 field goals attempted
# 14.3 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 8 rebounds
# 3 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# +5 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13415
# 0 points
# 10 minutes
# 0 field goals made
# 1 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 2 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13430
# 17 points
# 35 minutes
# 7 field goals made
# 11 field goals attempted
# 63.6 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 15 rebounds
# 1 assists
# 0 steals
# 3 turmnovers
# 6 blocks
# +19 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13430
# 5 points
# 23 minutes
# 2 field goals made
# 9 field goals attempted
# 22.2 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 5 three points attempted
# 20.0 %
# 2 rebounds
# 2 assists
# 1 steals
# 0 turmnovers
# 2 blocks
# -11 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13430
# 8 points
# 14 minutes
# 3 field goals made
# 3 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 2 three points attempted
# 100.0 %
# 2 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13430
# 29 points
# 34 minutes
# 11 field goals made
# 19 field goals attempted
# 57.9 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 4 three points made
# 7 three points attempted
# 57.1 %
# 3 rebounds
# 7 assists
# 2 steals
# 1 turmnovers
# 0 blocks
# +18 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13430
# 0 points
# 6 minutes
# 0 field goals made
# 2 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 1 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13430
# 7 points
# 21 minutes
# 3 field goals made
# 9 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 5 three points attempted
# 20.0 %
# 2 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13430
# 0 points
# 8 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 6 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +2 plus/minus
# ---------------------------------------------------------------------------
# id:  109
# Jordan
# Clarkson
# game_id: 13430
# 38 points
# 36 minutes
# 13 field goals made
# 26 field goals attempted
# 50.0 %
# 8 free throws made
# 9 free throws attempted
# 88.9 %
# 4 three points made
# 9 three points attempted
# 44.4 %
# 10 rebounds
# 7 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# +21 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13430
# 9 points
# 15 minutes
# 4 field goals made
# 9 field goals attempted
# 44.4 %
# 0 free throws made
# 1 free throws attempted
# 0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 1 rebounds
# 3 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13430
# 4 points
# 28 minutes
# 2 field goals made
# 5 field goals attempted
# 40.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 5 rebounds
# 4 assists
# 2 steals
# 3 turmnovers
# 1 blocks
# +9 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13430
# 10 points
# 20 minutes
# 4 field goals made
# 8 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 5 three points attempted
# 40.0 %
# 4 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +18 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13446
# 25 points
# 32 minutes
# 11 field goals made
# 20 field goals attempted
# 55.0 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 2 three points made
# 9 three points attempted
# 22.2 %
# 13 rebounds
# 0 assists
# 1 steals
# 0 turmnovers
# 2 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13446
# 7 points
# 19 minutes
# 3 field goals made
# 9 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 3 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13446
# 15 points
# 30 minutes
# 5 field goals made
# 8 field goals attempted
# 62.5 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 12 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13446
# 24 points
# 35 minutes
# 7 field goals made
# 17 field goals attempted
# 41.2 %
# 5 free throws made
# 6 free throws attempted
# 83.3 %
# 5 three points made
# 11 three points attempted
# 45.5 %
# 4 rebounds
# 7 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13446
# 11 points
# 29 minutes
# 5 field goals made
# 6 field goals attempted
# 83.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 1 three points attempted
# 100.0 %
# 2 rebounds
# 5 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13446
# 10 points
# 16 minutes
# 5 field goals made
# 6 field goals attempted
# 83.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 5 rebounds
# 3 assists
# 1 steals
# 0 turmnovers
# 3 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  109
# Jordan
# Clarkson
# game_id: 13446
# 15 points
# 34 minutes
# 5 field goals made
# 17 field goals attempted
# 29.4 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 2 three points made
# 9 three points attempted
# 22.2 %
# 0 rebounds
# 5 assists
# 1 steals
# 2 turmnovers
# 0 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13446
# 8 points
# 24 minutes
# 2 field goals made
# 8 field goals attempted
# 25.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 5 three points attempted
# 40.0 %
# 3 rebounds
# 5 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# -10 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13446
# 2 points
# 20 minutes
# 1 field goals made
# 5 field goals attempted
# 20.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 3 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +3 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13470
# 19 points
# 33 minutes
# 7 field goals made
# 10 field goals attempted
# 70.0 %
# 5 free throws made
# 8 free throws attempted
# 62.5 %
# 0 three points made
# 0 three points attempted
# 0 %
# 7 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# +6 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13470
# 16 points
# 32 minutes
# 7 field goals made
# 11 field goals attempted
# 63.6 %
# 2 free throws made
# 3 free throws attempted
# 66.7 %
# 0 three points made
# 3 three points attempted
# 0 %
# 2 rebounds
# 3 assists
# 3 steals
# 5 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13470
# 6 points
# 24 minutes
# 3 field goals made
# 9 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 11 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# -19 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13470
# 17 points
# 36 minutes
# 6 field goals made
# 17 field goals attempted
# 35.3 %
# 4 free throws made
# 5 free throws attempted
# 80.0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 1 rebounds
# 4 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13470
# 29 points
# 38 minutes
# 10 field goals made
# 17 field goals attempted
# 58.8 %
# 4 free throws made
# 5 free throws attempted
# 80.0 %
# 5 three points made
# 8 three points attempted
# 62.5 %
# 5 rebounds
# 6 assists
# 0 steals
# 4 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13470
# 7 points
# 15 minutes
# 2 field goals made
# 6 field goals attempted
# 33.3 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 5 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 1 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13470
# 0 points
# 4 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -10 plus/minus
# ---------------------------------------------------------------------------
# id:  109
# Jordan
# Clarkson
# game_id: 13470
# 22 points
# 28 minutes
# 10 field goals made
# 18 field goals attempted
# 55.6 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 4 rebounds
# 3 assists
# 3 steals
# 3 turmnovers
# 0 blocks
# -29 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13470
# 3 points
# 9 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -16 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13470
# 0 points
# 15 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 1 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -22 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13470
# 2 points
# 6 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 0 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -12 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13491
# 10 points
# 29 minutes
# 2 field goals made
# 9 field goals attempted
# 22.2 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 4 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13491
# 7 points
# 14 minutes
# 2 field goals made
# 4 field goals attempted
# 50.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 1 three points made
# 1 three points attempted
# 100.0 %
# 7 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +5 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13491
# 2 points
# 23 minutes
# 1 field goals made
# 5 field goals attempted
# 20.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 4 rebounds
# 4 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13491
# 20 points
# 31 minutes
# 9 field goals made
# 16 field goals attempted
# 56.3 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 7 rebounds
# 5 assists
# 0 steals
# 5 turmnovers
# 1 blocks
# -8 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13491
# 26 points
# 35 minutes
# 9 field goals made
# 17 field goals attempted
# 52.9 %
# 3 free throws made
# 4 free throws attempted
# 75.0 %
# 5 three points made
# 10 three points attempted
# 50.0 %
# 1 rebounds
# 6 assists
# 0 steals
# 3 turmnovers
# 2 blocks
# -26 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13491
# 8 points
# 13 minutes
# 3 field goals made
# 3 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 2 three points attempted
# 100.0 %
# 2 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13491
# 2 points
# 19 minutes
# 1 field goals made
# 1 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 8 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# -12 plus/minus
# ---------------------------------------------------------------------------
# id:  109
# Jordan
# Clarkson
# game_id: 13491
# 21 points
# 34 minutes
# 10 field goals made
# 18 field goals attempted
# 55.6 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 0 rebounds
# 2 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# -21 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13491
# 5 points
# 17 minutes
# 2 field goals made
# 7 field goals attempted
# 28.6 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 2 rebounds
# 0 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -11 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13491
# 6 points
# 24 minutes
# 2 field goals made
# 6 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 3 rebounds
# 4 assists
# 1 steals
# 0 turmnovers
# 1 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13514
# 18 points
# 30 minutes
# 7 field goals made
# 10 field goals attempted
# 70.0 %
# 2 free throws made
# 3 free throws attempted
# 66.7 %
# 2 three points made
# 2 three points attempted
# 100.0 %
# 11 rebounds
# 2 assists
# 0 steals
# 2 turmnovers
# 1 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13514
# 3 points
# 19 minutes
# 1 field goals made
# 7 field goals attempted
# 14.3 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 10 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 3 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13514
# 14 points
# 28 minutes
# 5 field goals made
# 9 field goals attempted
# 55.6 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 0 three points made
# 4 three points attempted
# 0 %
# 4 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13514
# 21 points
# 31 minutes
# 9 field goals made
# 16 field goals attempted
# 56.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 3 three points made
# 6 three points attempted
# 50.0 %
# 4 rebounds
# 6 assists
# 2 steals
# 1 turmnovers
# 0 blocks
# +6 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13514
# 25 points
# 35 minutes
# 8 field goals made
# 19 field goals attempted
# 42.1 %
# 8 free throws made
# 8 free throws attempted
# 100.0 %
# 1 three points made
# 7 three points attempted
# 14.3 %
# 4 rebounds
# 5 assists
# 2 steals
# 2 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13514
# 11 points
# 14 minutes
# 4 field goals made
# 4 field goals attempted
# 100.0 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 2 three points made
# 2 three points attempted
# 100.0 %
# 2 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +3 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13514
# 6 points
# 26 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 9 rebounds
# 1 assists
# 1 steals
# 2 turmnovers
# 2 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13514
# 5 points
# 19 minutes
# 1 field goals made
# 6 field goals attempted
# 16.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 0 rebounds
# 5 assists
# 1 steals
# 1 turmnovers
# 1 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  2842
# Jason
# Preston
# game_id: 13514
# 2 points
# 12 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 2 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +6 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13514
# 19 points
# 25 minutes
# 7 field goals made
# 11 field goals attempted
# 63.6 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 5 three points made
# 8 three points attempted
# 62.5 %
# 3 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +3 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13522
# 15 points
# 33 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 3 free throws made
# 4 free throws attempted
# 75.0 %
# 2 three points made
# 7 three points attempted
# 28.6 %
# 10 rebounds
# 1 assists
# 1 steals
# 1 turmnovers
# 1 blocks
# -23 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13522
# 8 points
# 27 minutes
# 4 field goals made
# 12 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 5 three points attempted
# 0 %
# 7 rebounds
# 2 assists
# 0 steals
# 3 turmnovers
# 0 blocks
# -20 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13522
# 7 points
# 30 minutes
# 3 field goals made
# 4 field goals attempted
# 75.0 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 10 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# -19 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13522
# 4 points
# 24 minutes
# 2 field goals made
# 7 field goals attempted
# 28.6 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 3 rebounds
# 3 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -17 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13522
# 18 points
# 30 minutes
# 5 field goals made
# 16 field goals attempted
# 31.3 %
# 7 free throws made
# 8 free throws attempted
# 87.5 %
# 1 three points made
# 7 three points attempted
# 14.3 %
# 3 rebounds
# 2 assists
# 0 steals
# 4 turmnovers
# 0 blocks
# -13 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13522
# 14 points
# 18 minutes
# 6 field goals made
# 7 field goals attempted
# 85.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 5 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 3 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13522
# 2 points
# 13 minutes
# 0 field goals made
# 1 field goals attempted
# 0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 3 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +9 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13522
# 22 points
# 31 minutes
# 9 field goals made
# 16 field goals attempted
# 56.3 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 2 rebounds
# 10 assists
# 1 steals
# 5 turmnovers
# 0 blocks
# -11 plus/minus
# ---------------------------------------------------------------------------
# id:  2842
# Jason
# Preston
# game_id: 13522
# 2 points
# 13 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 4 rebounds
# 5 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13522
# 8 points
# 22 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 4 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13535
# 11 points
# 20 minutes
# 5 field goals made
# 9 field goals attempted
# 55.6 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 6 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  830
# Lauri
# Markkanen
# game_id: 13535
# 22 points
# 31 minutes
# 8 field goals made
# 16 field goals attempted
# 50.0 %
# 5 free throws made
# 5 free throws attempted
# 100.0 %
# 1 three points made
# 5 three points attempted
# 20.0 %
# 12 rebounds
# 1 assists
# 2 steals
# 6 turmnovers
# 1 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13535
# 8 points
# 28 minutes
# 3 field goals made
# 6 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 6 rebounds
# 1 assists
# 1 steals
# 0 turmnovers
# 1 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13535
# 8 points
# 27 minutes
# 3 field goals made
# 9 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 3 rebounds
# 5 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +2 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13535
# 15 points
# 30 minutes
# 6 field goals made
# 12 field goals attempted
# 50.0 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 3 rebounds
# 8 assists
# 1 steals
# 6 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13535
# 3 points
# 15 minutes
# 1 field goals made
# 5 field goals attempted
# 20.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 1 rebounds
# 3 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13535
# 6 points
# 28 minutes
# 2 field goals made
# 3 field goals attempted
# 66.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 14 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 1 blocks
# -14 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13535
# 24 points
# 37 minutes
# 9 field goals made
# 17 field goals attempted
# 52.9 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 5 three points made
# 8 three points attempted
# 62.5 %
# 1 rebounds
# 2 assists
# 0 steals
# 4 turmnovers
# 0 blocks
# -10 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13535
# 0 points
# 7 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -10 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13535
# 7 points
# 19 minutes
# 2 field goals made
# 7 field goals attempted
# 28.6 %
# 2 free throws made
# 3 free throws attempted
# 66.7 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 1 rebounds
# 3 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  4032
# Taevion
# Kinsey
# game_id: 13535
# 0 points
# 0 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13548
# 16 points
# 23 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 6 rebounds
# 0 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# -23 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13548
# 12 points
# 24 minutes
# 3 field goals made
# 6 field goals attempted
# 50.0 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 2 three points made
# 5 three points attempted
# 40.0 %
# 4 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 3 blocks
# -22 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13548
# 4 points
# 20 minutes
# 2 field goals made
# 9 field goals attempted
# 22.2 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 6 rebounds
# 1 assists
# 1 steals
# 4 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13548
# 5 points
# 23 minutes
# 2 field goals made
# 5 field goals attempted
# 40.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 1 rebounds
# 3 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# -15 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13548
# 9 points
# 28 minutes
# 3 field goals made
# 14 field goals attempted
# 21.4 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 0 three points made
# 7 three points attempted
# 0 %
# 7 rebounds
# 2 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -23 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13548
# 0 points
# 4 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +7 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13548
# 6 points
# 4 minutes
# 2 field goals made
# 2 field goals attempted
# 100.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 3 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +7 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13548
# 3 points
# 15 minutes
# 1 field goals made
# 2 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 3 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 1 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13548
# 4 points
# 23 minutes
# 2 field goals made
# 2 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 8 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 1 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13548
# 25 points
# 30 minutes
# 12 field goals made
# 19 field goals attempted
# 63.2 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 5 rebounds
# 7 assists
# 2 steals
# 2 turmnovers
# 0 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13548
# 6 points
# 4 minutes
# 2 field goals made
# 3 field goals attempted
# 66.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +7 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13548
# 8 points
# 16 minutes
# 3 field goals made
# 10 field goals attempted
# 30.0 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 1 three points made
# 5 three points attempted
# 20.0 %
# 2 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  4032
# Taevion
# Kinsey
# game_id: 13548
# 0 points
# 0 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  2842
# Jason
# Preston
# game_id: 13548
# 0 points
# 4 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# +7 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13548
# 9 points
# 20 minutes
# 3 field goals made
# 6 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 3 three points made
# 6 three points attempted
# 50.0 %
# 1 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +3 plus/minus
# ---------------------------------------------------------------------------
# id:  830
# Lauri
# Markkanen
# game_id: 13556
# 21 points
# 36 minutes
# 6 field goals made
# 20 field goals attempted
# 30.0 %
# 8 free throws made
# 8 free throws attempted
# 100.0 %
# 1 three points made
# 9 three points attempted
# 11.1 %
# 3 rebounds
# 2 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -19 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13556
# 5 points
# 28 minutes
# 2 field goals made
# 4 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 2 rebounds
# 0 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13556
# 14 points
# 27 minutes
# 7 field goals made
# 7 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 9 rebounds
# 2 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13556
# 4 points
# 20 minutes
# 2 field goals made
# 3 field goals attempted
# 66.7 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 4 rebounds
# 5 assists
# 1 steals
# 4 turmnovers
# 1 blocks
# +10 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13556
# 18 points
# 33 minutes
# 6 field goals made
# 16 field goals attempted
# 37.5 %
# 5 free throws made
# 5 free throws attempted
# 100.0 %
# 1 three points made
# 6 three points attempted
# 16.7 %
# 2 rebounds
# 5 assists
# 1 steals
# 6 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13556
# 3 points
# 20 minutes
# 1 field goals made
# 7 field goals attempted
# 14.3 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 4 three points attempted
# 0 %
# 8 rebounds
# 5 assists
# 1 steals
# 2 turmnovers
# 2 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13556
# 10 points
# 21 minutes
# 4 field goals made
# 7 field goals attempted
# 57.1 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 5 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13556
# 2 points
# 7 minutes
# 1 field goals made
# 2 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13556
# 20 points
# 34 minutes
# 9 field goals made
# 14 field goals attempted
# 64.3 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 4 rebounds
# 5 assists
# 0 steals
# 3 turmnovers
# 0 blocks
# -21 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13556
# 0 points
# 7 minutes
# 0 field goals made
# 2 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 3 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  4032
# Taevion
# Kinsey
# game_id: 13556
# 0 points
# 0 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13556
# 0 points
# 8 minutes
# 0 field goals made
# 1 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13572
# 25 points
# 20 minutes
# 7 field goals made
# 9 field goals attempted
# 77.8 %
# 9 free throws made
# 10 free throws attempted
# 90.0 %
# 2 three points made
# 2 three points attempted
# 100.0 %
# 6 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -16 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13572
# 9 points
# 27 minutes
# 4 field goals made
# 9 field goals attempted
# 44.4 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 6 rebounds
# 0 assists
# 0 steals
# 1 turmnovers
# 1 blocks
# -17 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13572
# 20 points
# 36 minutes
# 7 field goals made
# 17 field goals attempted
# 41.2 %
# 5 free throws made
# 6 free throws attempted
# 83.3 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 2 rebounds
# 8 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13572
# 8 points
# 21 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 0 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13572
# 15 points
# 31 minutes
# 4 field goals made
# 13 field goals attempted
# 30.8 %
# 5 free throws made
# 6 free throws attempted
# 83.3 %
# 2 three points made
# 9 three points attempted
# 22.2 %
# 4 rebounds
# 5 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -30 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13572
# 16 points
# 27 minutes
# 5 field goals made
# 14 field goals attempted
# 35.7 %
# 4 free throws made
# 5 free throws attempted
# 80.0 %
# 2 three points made
# 10 three points attempted
# 20.0 %
# 4 rebounds
# 4 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -14 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13572
# 0 points
# 18 minutes
# 0 field goals made
# 2 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 3 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13572
# 12 points
# 28 minutes
# 5 field goals made
# 8 field goals attempted
# 62.5 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 9 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 3 blocks
# -12 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13572
# 12 points
# 25 minutes
# 4 field goals made
# 9 field goals attempted
# 44.4 %
# 3 free throws made
# 4 free throws attempted
# 75.0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 5 rebounds
# 4 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -11 plus/minus
# ---------------------------------------------------------------------------
# id:  152
# Kris
# Dunn
# game_id: 13572
# 2 points
# 6 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -20 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13589
# 21 points
# 31 minutes
# 9 field goals made
# 16 field goals attempted
# 56.3 %
# 1 free throws made
# 3 free throws attempted
# 33.3 %
# 2 three points made
# 5 three points attempted
# 40.0 %
# 11 rebounds
# 2 assists
# 2 steals
# 0 turmnovers
# 0 blocks
# -10 plus/minus
# ---------------------------------------------------------------------------
# id:  830
# Lauri
# Markkanen
# game_id: 13589
# 34 points
# 34 minutes
# 10 field goals made
# 19 field goals attempted
# 52.6 %
# 8 free throws made
# 8 free throws attempted
# 100.0 %
# 6 three points made
# 9 three points attempted
# 66.7 %
# 7 rebounds
# 2 assists
# 1 steals
# 1 turmnovers
# 1 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13589
# 8 points
# 29 minutes
# 3 field goals made
# 8 field goals attempted
# 37.5 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 1 three points made
# 5 three points attempted
# 20.0 %
# 6 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# -8 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13589
# 20 points
# 29 minutes
# 8 field goals made
# 15 field goals attempted
# 53.3 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 3 three points made
# 6 three points attempted
# 50.0 %
# 2 rebounds
# 6 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -15 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13589
# 6 points
# 35 minutes
# 2 field goals made
# 11 field goals attempted
# 18.2 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 6 three points attempted
# 0 %
# 5 rebounds
# 6 assists
# 2 steals
# 3 turmnovers
# 0 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13589
# 0 points
# 1 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13589
# 3 points
# 16 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 3 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13589
# 0 points
# 1 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 1 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13589
# 0 points
# 1 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13589
# 9 points
# 17 minutes
# 4 field goals made
# 4 field goals attempted
# 100.0 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 4 rebounds
# 0 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  109
# Jordan
# Clarkson
# game_id: 13589
# 4 points
# 33 minutes
# 0 field goals made
# 7 field goals attempted
# 0 %
# 4 free throws made
# 5 free throws attempted
# 80.0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 4 rebounds
# 8 assists
# 0 steals
# 5 turmnovers
# 0 blocks
# -11 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13589
# 0 points
# 1 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13589
# 0 points
# 13 minutes
# 0 field goals made
# 4 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 4 three points attempted
# 0 %
# 3 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  761
# John
# Collins
# game_id: 13606
# 18 points
# 23 minutes
# 5 field goals made
# 10 field goals attempted
# 50.0 %
# 6 free throws made
# 6 free throws attempted
# 100.0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 5 rebounds
# 1 assists
# 2 steals
# 4 turmnovers
# 0 blocks
# +2 plus/minus
# ---------------------------------------------------------------------------
# id:  830
# Lauri
# Markkanen
# game_id: 13606
# 25 points
# 42 minutes
# 8 field goals made
# 17 field goals attempted
# 47.1 %
# 6 free throws made
# 6 free throws attempted
# 100.0 %
# 3 three points made
# 7 three points attempted
# 42.9 %
# 6 rebounds
# 2 assists
# 1 steals
# 3 turmnovers
# 0 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13606
# 8 points
# 33 minutes
# 3 field goals made
# 8 field goals attempted
# 37.5 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 8 rebounds
# 1 assists
# 2 steals
# 0 turmnovers
# 1 blocks
# +6 plus/minus
# ---------------------------------------------------------------------------
# id:  1021
# Collin
# Sexton
# game_id: 13606
# 26 points
# 38 minutes
# 11 field goals made
# 20 field goals attempted
# 55.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 2 rebounds
# 9 assists
# 2 steals
# 3 turmnovers
# 1 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13606
# 14 points
# 40 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 1 rebounds
# 8 assists
# 0 steals
# 5 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13606
# 0 points
# 10 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 2 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 5 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13606
# 9 points
# 13 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 1 rebounds
# 1 assists
# 1 steals
# 2 turmnovers
# 0 blocks
# -8 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13606
# 2 points
# 3 minutes
# 1 field goals made
# 2 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13606
# 0 points
# 6 minutes
# 0 field goals made
# 0 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 1 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  3457
# Walker
# Kessler
# game_id: 13606
# 4 points
# 22 minutes
# 1 field goals made
# 3 field goals attempted
# 33.3 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 6 rebounds
# 1 assists
# 0 steals
# 2 turmnovers
# 2 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13606
# 5 points
# 6 minutes
# 2 field goals made
# 4 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 1 rebounds
# 0 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# ...
# -12 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13690
# 25 points
# 34 minutes
# 8 field goals made
# 16 field goals attempted
# 50.0 %
# 5 free throws made
# 5 free throws attempted
# 100.0 %
# 4 three points made
# 11 three points attempted
# 36.4 %
# 2 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13690
# 0 points
# 5 minutes
# 0 field goals made
# 4 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  1847
# Darius
# Bazley
# game_id: 13690
# 6 points
# 30 minutes
# 2 field goals made
# 3 field goals attempted
# 66.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 4 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13690
# 5 points
# 21 minutes
# 2 field goals made
# 8 field goals attempted
# 25.0 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 5 rebounds
# 3 assists
# 1 steals
# 0 turmnovers
# 1 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13690
# 5 points
# 16 minutes
# 2 field goals made
# 4 field goals attempted
# 50.0 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 2 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13690
# 27 points
# 33 minutes
# 9 field goals made
# 12 field goals attempted
# 75.0 %
# 2 free throws made
# 3 free throws attempted
# 66.7 %
# 7 three points made
# 8 three points attempted
# 87.5 %
# 2 rebounds
# 1 assists
# 1 steals
# 2 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13702
# 15 points
# 35 minutes
# 6 field goals made
# 15 field goals attempted
# 40.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 10 rebounds
# 3 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -24 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13702
# 3 points
# 22 minutes
# 1 field goals made
# 5 field goals attempted
# 20.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 5 rebounds
# 1 assists
# 1 steals
# 0 turmnovers
# 1 blocks
# -7 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13702
# 20 points
# 37 minutes
# 9 field goals made
# 14 field goals attempted
# 64.3 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 11 rebounds
# 2 assists
# 2 steals
# 3 turmnovers
# 0 blocks
# -16 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13702
# 5 points
# 32 minutes
# 2 field goals made
# 8 field goals attempted
# 25.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 4 three points attempted
# 25.0 %
# 2 rebounds
# 3 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# -22 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13702
# 10 points
# 30 minutes
# 4 field goals made
# 11 field goals attempted
# 36.4 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 9 three points attempted
# 22.2 %
# 3 rebounds
# 5 assists
# 0 steals
# 5 turmnovers
# 0 blocks
# -15 plus/minus
# ---------------------------------------------------------------------------
# id:  1847
# Darius
# Bazley
# game_id: 13702
# 8 points
# 25 minutes
# 2 field goals made
# 5 field goals attempted
# 40.0 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 5 rebounds
# 0 assists
# 1 steals
# 0 turmnovers
# 0 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13702
# 10 points
# 21 minutes
# 2 field goals made
# 9 field goals attempted
# 22.2 %
# 5 free throws made
# 5 free throws attempted
# 100.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 5 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13702
# 24 points
# 32 minutes
# 10 field goals made
# 23 field goals attempted
# 43.5 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 4 three points made
# 8 three points attempted
# 50.0 %
# 3 rebounds
# 2 assists
# 1 steals
# 4 turmnovers
# 1 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  2842
# Jason
# Preston
# game_id: 13702
# 0 points
# 6 minutes
# 0 field goals made
# 1 field goals attempted
# 0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +8 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13716
# 22 points
# 34 minutes
# 7 field goals made
# 17 field goals attempted
# 41.2 %
# 7 free throws made
# 9 free throws attempted
# 77.8 %
# 1 three points made
# 7 three points attempted
# 14.3 %
# 6 rebounds
# 2 assists
# 1 steals
# 2 turmnovers
# 0 blocks
# +7 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13716
# 5 points
# 19 minutes
# 2 field goals made
# 3 field goals attempted
# 66.7 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 4 rebounds
# 4 assists
# 3 steals
# 0 turmnovers
# 1 blocks
# +3 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13716
# 10 points
# 19 minutes
# 5 field goals made
# 9 field goals attempted
# 55.6 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 5 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -3 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13716
# 10 points
# 24 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 2 rebounds
# 1 assists
# 0 steals
# 3 turmnovers
# 1 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13716
# 20 points
# 33 minutes
# 7 field goals made
# 14 field goals attempted
# 50.0 %
# 4 free throws made
# 5 free throws attempted
# 80.0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 4 rebounds
# 5 assists
# 2 steals
# 5 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  1847
# Darius
# Bazley
# game_id: 13716
# 8 points
# 23 minutes
# 4 field goals made
# 5 field goals attempted
# 80.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 7 rebounds
# 2 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  3463
# Kenneth
# Lofton Jr.
# game_id: 13716
# 14 points
# 27 minutes
# 5 field goals made
# 7 field goals attempted
# 71.4 %
# 2 free throws made
# 4 free throws attempted
# 50.0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 9 rebounds
# 5 assists
# 2 steals
# 2 turmnovers
# 1 blocks
# +5 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13716
# 17 points
# 24 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 4 three points made
# 9 three points attempted
# 44.4 %
# 6 rebounds
# 3 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +4 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13716
# 2 points
# 8 minutes
# 1 field goals made
# 2 field goals attempted
# 50.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 1 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -5 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13716
# 16 points
# 29 minutes
# 5 field goals made
# 13 field goals attempted
# 38.5 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 2 three points made
# 6 three points attempted
# 33.3 %
# 5 rebounds
# 5 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# +6 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13732
# 11 points
# 28 minutes
# 4 field goals made
# 9 field goals attempted
# 44.4 %
# 3 free throws made
# 5 free throws attempted
# 60.0 %
# 0 three points made
# 3 three points attempted
# 0 %
# 6 rebounds
# 2 assists
# 1 steals
# 2 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13732
# 7 points
# 23 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 3 three points attempted
# 33.3 %
# 5 rebounds
# 1 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13732
# 4 points
# 13 minutes
# 1 field goals made
# 4 field goals attempted
# 25.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 10 rebounds
# 3 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# 0 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13732
# 12 points
# 23 minutes
# 4 field goals made
# 6 field goals attempted
# 66.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 0 rebounds
# 2 assists
# 2 steals
# 1 turmnovers
# 0 blocks
# +10 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13732
# 14 points
# 28 minutes
# 5 field goals made
# 15 field goals attempted
# 33.3 %
# 2 free throws made
# 3 free throws attempted
# 66.7 %
# 2 three points made
# 7 three points attempted
# 28.6 %
# 1 rebounds
# 2 assists
# 0 steals
# 5 turmnovers
# 0 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  1847
# Darius
# Bazley
# game_id: 13732
# 12 points
# 23 minutes
# 5 field goals made
# 7 field goals attempted
# 71.4 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 5 rebounds
# 1 assists
# 2 steals
# 2 turmnovers
# 1 blocks
# -1 plus/minus
# ---------------------------------------------------------------------------
# id:  3463
# Kenneth
# Lofton Jr.
# game_id: 13732
# 27 points
# 35 minutes
# 10 field goals made
# 16 field goals attempted
# 62.5 %
# 7 free throws made
# 7 free throws attempted
# 100.0 %
# 0 three points made
# 5 three points attempted
# 0 %
# 9 rebounds
# 8 assists
# 1 steals
# 3 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13732
# 9 points
# 21 minutes
# 3 field goals made
# 8 field goals attempted
# 37.5 %
# 3 free throws made
# 3 free throws attempted
# 100.0 %
# 0 three points made
# 4 three points attempted
# 0 %
# 3 rebounds
# 1 assists
# 1 steals
# 0 turmnovers
# 2 blocks
# -6 plus/minus
# ---------------------------------------------------------------------------
# id:  1867
# Talen
# Horton-Tucker
# game_id: 13732
# 12 points
# 29 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 0 three points made
# 5 three points attempted
# 0 %
# 1 rebounds
# 4 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  2842
# Jason
# Preston
# game_id: 13732
# 2 points
# 18 minutes
# 1 field goals made
# 6 field goals attempted
# 16.7 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 6 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# +8 plus/minus
# ---------------------------------------------------------------------------
# id:  1891
# Luka
# Samanic
# game_id: 13746
# 14 points
# 29 minutes
# 5 field goals made
# 11 field goals attempted
# 45.5 %
# 4 free throws made
# 4 free throws attempted
# 100.0 %
# 0 three points made
# 5 three points attempted
# 0 %
# 5 rebounds
# 2 assists
# 1 steals
# 7 turmnovers
# 0 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  4031
# Taylor
# Hendricks
# game_id: 13746
# 16 points
# 41 minutes
# 6 field goals made
# 10 field goals attempted
# 60.0 %
# 2 free throws made
# 2 free throws attempted
# 100.0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 8 rebounds
# 2 assists
# 3 steals
# 1 turmnovers
# 1 blocks
# +2 plus/minus
# ---------------------------------------------------------------------------
# id:  2785
# Omer
# Yurtseven
# game_id: 13746
# 11 points
# 30 minutes
# 5 field goals made
# 12 field goals attempted
# 41.7 %
# 1 free throws made
# 2 free throws attempted
# 50.0 %
# 0 three points made
# 1 three points attempted
# 0 %
# 18 rebounds
# 2 assists
# 0 steals
# 2 turmnovers
# 0 blocks
# +1 plus/minus
# ---------------------------------------------------------------------------
# id:  3454
# Johnny
# Juzang
# game_id: 13746
# 8 points
# 19 minutes
# 2 field goals made
# 5 field goals attempted
# 40.0 %
# 2 free throws made
# 4 free throws attempted
# 50.0 %
# 2 three points made
# 4 three points attempted
# 50.0 %
# 1 rebounds
# 2 assists
# 0 steals
# 0 turmnovers
# 0 blocks
# +13 plus/minus
# ---------------------------------------------------------------------------
# id:  4029
# Keyonte
# George
# game_id: 13746
# 21 points
# 20 minutes
# 8 field goals made
# 11 field goals attempted
# 72.7 %
# 0 free throws made
# 1 free throws attempted
# 0 %
# 5 three points made
# 6 three points attempted
# 83.3 %
# 1 rebounds
# 4 assists
# 0 steals
# 1 turmnovers
# 0 blocks
# +13 plus/minus
# ---------------------------------------------------------------------------
# id:  1847
# Darius
# Bazley
# game_id: 13746
# 2 points
# 7 minutes
# 1 field goals made
# 1 field goals attempted
# 100.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 0 three points made
# 0 three points attempted
# 0 %
# 0 rebounds
# 0 assists
# 0 steals
# 0 turmnovers
# 1 blocks
# -9 plus/minus
# ---------------------------------------------------------------------------
# id:  3463
# Kenneth
# Lofton Jr.
# game_id: 13746
# 7 points
# 16 minutes
# 3 field goals made
# 5 field goals attempted
# 60.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 1 three points made
# 2 three points attempted
# 50.0 %
# 1 rebounds
# 6 assists
# 0 steals
# 1 turmnovers
# 1 blocks
# -4 plus/minus
# ---------------------------------------------------------------------------
# id:  4034
# Brice
# Sensabaugh
# game_id: 13746
# 14 points
# 29 minutes
# 6 field goals made
# 15 field goals attempted
# 40.0 %
# 0 free throws made
# 0 free throws attempted
# 0 %
# 2 three points made
# 7 three points attempted
# 28.6 %
# 3 rebounds
# 0 assists
# 1 steals
# 5 turmnovers
# 0 blocks
# -20 plus/minus
# ---------------------------------------------------------------------------
# id:  3358
# Micah
# Potter
# game_id: 13746
# 10 points
# 21 minutes
# 4 field goals made
# 7 field goals attempted
# 57.1 %
# 0 free throws made
# 2 free throws attempted
# 0 %
# 2 three points made
# 3 three points attempted
# 66.7 %
# 8 rebounds
# 1 assists
# 0 steals
# 1 turmnovers
# 2 blocks
# -2 plus/minus
# ---------------------------------------------------------------------------
# id:  2611
# Kira
# Lewis Jr.
# game_id: 13746
# 13 points
# 28 minutes
# 6 field goals made
# 12 field goals attempted
# 50.0 %
# 1 free throws made
# 1 free throws attempted
# 100.0 %
# 0 three points made
# 2 three points attempted
# 0 %
# 3 rebounds
# 3 assists
# 1 steals
# 1 turmnovers
# 0 blocks
# -20 plus/minus
# ---------------------------------------------------------------------------

# %%
# checking that it is a dictionary
type(jazz_player_data_per_game)
# Out:
# dict

# %%
# Convert the list of player data dictionaries to a DataFrame
players_df = pd.DataFrame(jazz_player_data_per_game)

# Display the DataFrame
players_df.head()
# Out:
#      id firstname       lastname   game  points min  fgm  fga   fgp  ftm  ...  \
# 0   761      John        Collins  12485       5  18    2    3  66.7    0  ...
# 1   830     Lauri      Markkanen  12485      10  18    4   10  40.0    2  ...
# 2  3457    Walker        Kessler  12485       7  24    3    5  60.0    1  ...
# 3  1021    Collin         Sexton  12485       3  18    1    6  16.7    1  ...
# 4  1867     Talen  Horton-Tucker  12485      13  21    5   13  38.5    0  ...
#
#      ftp tpm  tpa    tpp totReb  assists  steals  turnovers  blocks  plusMinus
# 0      0   1    1  100.0      4        0       0          2       0         -2
# 1  100.0   0    3      0      8        2       0          3       0         -4
# 2   33.3   0    0      0      7        1       0          2       5         -5
# 3   50.0   0    2      0      1        5       0          4       0         -4
# 4      0   3    7   42.9      6        1       0          1       0         -7
#
# [5 rows x 21 columns]

# %%
# turn into csv without index
players_df.to_csv('jazz_player_data_per_game', index=False)

# %%
# adding secret for connection password
db_password = userdata.get('RDS_PASSWORD')

# %%
# create engine to connect with database
engine = create_engine(f'mysql+mysqldb://admin:{db_password}@sql-project.ca9jkrwdnacm.us-east-1.rds.amazonaws.com/JazzData')

# %%
# transitioning the dataframe into sql
players_df.to_sql('PlayerData', engine, if_exists='replace', index=False)
# Out:
# 966

# %% [markdown]
# # Getting game info (teams, win, loss, date, etc.)

# %%
# https://rapidapi.com/api-sports/api/api-nba (games per team and season)

url = "https://api-nba-v1.p.rapidapi.com/games"

# utah jazz id is 40 and for 2023 season
querystring = {"season":"2023","team":"40"}

# adding headers for authentication
api_key = userdata.get('RAPID_API_KEY_GAME_IDS')


headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'get': 'games/', 'parameters': {'season': '2023', 'team': '40'}, 'errors': [], 'results': 88, 'response': [{'id': 12485, 'league': 'standard', 'season': 2023, 'date': {'start': '2023-10-09T01:00:00.000Z', 'end': None, 'duration': None}, 'stage': 1, 'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'}, 'periods': {'current': 0, 'total': 4, 'endOfPeriod': False}, 'arena': {'name': 'Stan Sheriff Center', 'city': 'Honolulu', 'state': 'HI', 'country': None}, 'teams': {'visitors': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'home': {'id': 16, 'name': 'LA Clippers', 'nickname': 'Clippers', 'code': 'LAC', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}}, 'scores': {'visitors': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['24', '19', '26', '32'], 'points': 101}, 'home': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['27', '23', '16', '30'], 'points': 96}}, 'officials': [], 'timesTied': None, 'leadChanges': None, 'nugget': None}, {'id': 12495, 'league': 'standard', 'season': 2023, 'date': {'start': '2023-10-11T02:00:00.000Z', 'end': None, 'duration': None}, 'stage': 1, 'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'}, 'periods': {'current': 4, 'total': 4, 'endOfPeriod': False}, 'arena': {'name': 'Climate Pledge Arena', 'city': 'Seattle', 'state': 'WA', 'country': None}, 'teams': {'visitors': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}, 'home': {'id': 16, 'name': 'LA Clippers', 'nickname': 'Clippers', 'code': 'LAC', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}}, 'scores': {'visitors': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['21', '18', '30', '29'], 'points': 98}, 'home': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['29', '20', '23', '31'], 'points': 103}}, 'officials': [], 'timesTied': None, 'leadChanges': None, 'nugget': None}, {'id': 12512, 'league': 'standard', 'season': 2023, 'date': {'start': '2023-10-15T01:00:00.000Z', 'end': None, 'duration': None}, 'stage': 1, 'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'}, 'periods': {'current': 4, 'total': 4, 'endOfPeriod': False}, 'arena': {'name': 'Delta Center', 'city': 'Salt Lake City', 'state': 'UT', 'country': None}, 'teams': {'visitors': {'id': 29, 'name': 'Portland Trail Blazers', 'nickname': 'Trail Blazers', 'code': 'POR', 'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'}, 'home': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}}, 'scores': {'visitors': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['34', '28', '35', '36'], 'points': 133}, 'home': {'win': 0, 'loss': 0, 'series': {'win': 0, 'loss': 0}, 'linescore': ['40', '35', '36', '27'], 'points': 138}}, 'officials': [], 'timesTied': None, 'leadChanges': None, 'nugget': None}, {'id': 12523, 'league': 'standard', 'season': 2023, 'date': {'start': '2023-10-17T01:00:00.000Z', 'end': None, 'duration': None}, 'stage': 1, 'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'}, 'periods': {'current': 4, 'total': 4, 'endOfPeriod': False}, 'arena': {'name': 'Delta Center', 'city': 'Salt Lake City', 'state': 'UT', 'country': None}, 'teams': {'visitors': {'id': 168, 'name': 'New Zealand Breakers', 'nickname': 'Breakers', 'code': 'BNZ', 'logo': ''}, 'home': {'id': 40, 'name': 'Utah Jazz', 'nickname': 'Jazz', 'code': 'UTA', 'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}}, 'scores': {'visitors': {'wi ...

# %%
# checking response code
response
# Out:
# <Response [200]>

# %%
# getting the text of response2
response.text
# Out:
# '{"get":"games\\/","parameters":{"season":"2023","team":"40"},"errors":[],"results":88,"response":[{"id":12485,"league":"standard","season":2023,"date":{"start":"2023-10-09T01:00:00.000Z","end":null,"duration":null},"stage":1,"status":{"clock":null,"halftime":false,"short":3,"long":"Finished"},"periods":{"current":0,"total":4,"endOfPeriod":false},"arena":{"name":"Stan Sheriff Center","city":"Honolulu","state":"HI","country":null},"teams":{"visitors":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"home":{"id":16,"name":"LA Clippers","nickname":"Clippers","code":"LAC","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/d\\/d6\\/Los_Angeles_Clippers_logo_2010.png"}},"scores":{"visitors":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["24","19","26","32"],"points":101},"home":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["27","23","16","30"],"points":96}},"officials":[],"timesTied":null,"leadChanges":null,"nugget":null},{"id":12495,"league":"standard","season":2023,"date":{"start":"2023-10-11T02:00:00.000Z","end":null,"duration":null},"stage":1,"status":{"clock":null,"halftime":false,"short":3,"long":"Finished"},"periods":{"current":4,"total":4,"endOfPeriod":false},"arena":{"name":"Climate Pledge Arena","city":"Seattle","state":"WA","country":null},"teams":{"visitors":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"},"home":{"id":16,"name":"LA Clippers","nickname":"Clippers","code":"LAC","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/d\\/d6\\/Los_Angeles_Clippers_logo_2010.png"}},"scores":{"visitors":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["21","18","30","29"],"points":98},"home":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["29","20","23","31"],"points":103}},"officials":[],"timesTied":null,"leadChanges":null,"nugget":null},{"id":12512,"league":"standard","season":2023,"date":{"start":"2023-10-15T01:00:00.000Z","end":null,"duration":null},"stage":1,"status":{"clock":null,"halftime":false,"short":3,"long":"Finished"},"periods":{"current":4,"total":4,"endOfPeriod":false},"arena":{"name":"Delta Center","city":"Salt Lake City","state":"UT","country":null},"teams":{"visitors":{"id":29,"name":"Portland Trail Blazers","nickname":"Trail Blazers","code":"POR","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/en\\/thumb\\/2\\/21\\/Portland_Trail_Blazers_logo.svg\\/1200px-Portland_Trail_Blazers_logo.svg.png"},"home":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"}},"scores":{"visitors":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["34","28","35","36"],"points":133},"home":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["40","35","36","27"],"points":138}},"officials":[],"timesTied":null,"leadChanges":null,"nugget":null},{"id":12523,"league":"standard","season":2023,"date":{"start":"2023-10-17T01:00:00.000Z","end":null,"duration":null},"stage":1,"status":{"clock":null,"halftime":false,"short":3,"long":"Finished"},"periods":{"current":4,"total":4,"endOfPeriod":false},"arena":{"name":"Delta Center","city":"Salt Lake City","state":"UT","country":null},"teams":{"visitors":{"id":168,"name":"New Zealand Breakers","nickname":"Breakers","code":"BNZ","logo":""},"home":{"id":40,"name":"Utah Jazz","nickname":"Jazz","code":"UTA","logo":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/fr\\/3\\/3b\\/Jazz_de_l%27Utah_logo.png"}},"scores":{"visitors":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["11","32","22","29"],"points":94},"home":{"win":0,"loss":0,"series":{"win":0,"loss":0},"linescore":["31","28","25","30"],"points":114}},"officials":[],"timesTied":null,"leadChanges":null,"nugget":null},{"id":12540,"league":"standard"," ...

# %%
# viewing the text response in json format
json.loads(response.text)
# Out:
# {'get': 'games/',
#  'parameters': {'season': '2023', 'team': '40'},
#  'errors': [],
#  'results': 88,
#  'response': [{'id': 12485,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-09T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 1,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 0, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Stan Sheriff Center',
#     'city': 'Honolulu',
#     'state': 'HI',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['24', '19', '26', '32'],
#      'points': 101},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '23', '16', '30'],
#      'points': 96}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12495,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-11T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 1,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Climate Pledge Arena',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['21', '18', '30', '29'],
#      'points': 98},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '20', '23', '31'],
#      'points': 103}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12512,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-15T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 1,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 29,
#      'name': 'Portland Trail Blazers',
#      'nickname': 'Trail Blazers',
#      'code': 'POR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '28', '35', '36'],
#      'points': 133},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['40', '35', '36', '27'],
#      'points': 138}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12523,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-17T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 1,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 168,
#      'name': 'New Zealand Breakers',
#      'nickname': 'Breakers',
#      'code': 'BNZ',
#      'logo': ''},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['11', '32', '22', '29'],
#      'points': 94},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['31', '28', '25', '30'],
#      'points': 114}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12540,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-20T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 1,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Golden 1 Center',
#     'city': 'Sacramento',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 30,
#      'name': 'Sacramento Kings',
#      'nickname': 'Kings',
#      'code': 'SAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['26', '23', '36', '28'],
#      'points': 113},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '27', '25', '37'],
#      'points': 116}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12560,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-26T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 30,
#      'name': 'Sacramento Kings',
#      'nickname': 'Kings',
#      'code': 'SAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '40', '33', '25'],
#      'points': 130},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['24', '34', '29', '27'],
#      'points': 114}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12573,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-28T01:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['30', '24', '29', '35'],
#      'points': 118},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['33', '30', '26', '31'],
#      'points': 120}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12582,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-29T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Footprint Center',
#     'city': 'Phoenix',
#     'state': 'AZ',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 28,
#      'name': 'Phoenix Suns',
#      'nickname': 'Suns',
#      'code': 'PHX',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '23', '28', '26'],
#      'points': 104},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['37', '29', '40', '20'],
#      'points': 126}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12598,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-10-31T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Ball Arena',
#     'city': 'Denver',
#     'state': 'CO',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 9,
#      'name': 'Denver Nuggets',
#      'nickname': 'Nuggets',
#      'code': 'DEN',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['21', '24', '24', '33'],
#      'points': 102},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['31', '27', '22', '30'],
#      'points': 110}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12613,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-02T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 19,
#      'name': 'Memphis Grizzlies',
#      'nickname': 'Grizzlies',
#      'code': 'MEM',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['19', '27', '33', '30'],
#      'points': 109},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['42', '37', '25', '29'],
#      'points': 133}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12618,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-03T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 26,
#      'name': 'Orlando Magic',
#      'nickname': 'Magic',
#      'code': 'ORL',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/b/bd/Orlando_Magic_logo_2010.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['30', '36', '24', '25'],
#      'points': 115},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '24', '28', '27'],
#      'points': 113}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12633,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-05T00:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Target Center',
#     'city': 'Minneapolis',
#     'state': 'MN',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 22,
#      'name': 'Minnesota Timberwolves',
#      'nickname': 'Timberwolves',
#      'code': 'MIN',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '23', '27', '18'],
#      'points': 95},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '26', '37', '31'],
#      'points': 123}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12647,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-07T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'United Center',
#     'city': 'Chicago',
#     'state': 'IL',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 6,
#      'name': 'Chicago Bulls',
#      'nickname': 'Bulls',
#      'code': 'CHI',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d1/Bulls_de_Chicago_logo.svg/1200px-Bulls_de_Chicago_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '20', '26', '35'],
#      'points': 113},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['37', '29', '32', '32'],
#      'points': 130}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12653,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-09T00:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Gainbridge Fieldhouse',
#     'city': 'Indianapolis',
#     'state': 'IN',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 15,
#      'name': 'Indiana Pacers',
#      'nickname': 'Pacers',
#      'code': 'IND',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '31', '38', '20'],
#      'points': 118},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '38', '34', '33'],
#      'points': 134}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12672,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-11T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'FedExForum',
#     'city': 'Memphis',
#     'state': 'TN',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 19,
#      'name': 'Memphis Grizzlies',
#      'nickname': 'Grizzlies',
#      'code': 'MEM',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '42', '27', '24'],
#      'points': 127},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '31', '32', '26'],
#      'points': 121}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12702,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-15T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 29,
#      'name': 'Portland Trail Blazers',
#      'nickname': 'Trail Blazers',
#      'code': 'POR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '30', '28', '13'],
#      'points': 99},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['36', '31', '28', '20'],
#      'points': 115}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12724,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-18T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 28,
#      'name': 'Phoenix Suns',
#      'nickname': 'Suns',
#      'code': 'PHX',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['41', '34', '27', '29'],
#      'points': 131},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['38', '37', '24', '29'],
#      'points': 128}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12739,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-20T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 28,
#      'name': 'Phoenix Suns',
#      'nickname': 'Suns',
#      'code': 'PHX',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['30', '31', '24', '30', '12'],
#      'points': 140},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['30', '26', '28', '31', '12'],
#      'points': 137}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12754,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-22T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'crypto.com Arena',
#     'city': 'Los Angeles',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 17,
#      'name': 'Los Angeles Lakers',
#      'nickname': 'Lakers',
#      'code': 'LAL',
#      'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Los_Angeles_Lakers_logo.svg/220px-Los_Angeles_Lakers_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['17', '24', '34', '24'],
#      'points': 99},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '30', '40', '29'],
#      'points': 131}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12767,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-23T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Moda Center',
#     'city': 'Portland',
#     'state': 'OR',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 29,
#      'name': 'Portland Trail Blazers',
#      'nickname': 'Trail Blazers',
#      'code': 'POR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['21', '25', '27', '32'],
#      'points': 105},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '33', '24', '32'],
#      'points': 121}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12783,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-26T02:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 23,
#      'name': 'New Orleans Pelicans',
#      'nickname': 'Pelicans',
#      'code': 'NOP',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '24', '24', '23'],
#      'points': 100},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['22', '21', '25', '37'],
#      'points': 105}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12796,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-28T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 23,
#      'name': 'New Orleans Pelicans',
#      'nickname': 'Pelicans',
#      'code': 'NOP',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['24', '31', '33', '24'],
#      'points': 112},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '25', '31', '26'],
#      'points': 114}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12809,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-11-30T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'FedExForum',
#     'city': 'Memphis',
#     'state': 'TN',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 19,
#      'name': 'Memphis Grizzlies',
#      'nickname': 'Grizzlies',
#      'code': 'MEM',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['25', '17', '25', '24'],
#      'points': 91},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['24', '36', '28', '17'],
#      'points': 105}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12818,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-01T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Target Center',
#     'city': 'Minneapolis',
#     'state': 'MN',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 22,
#      'name': 'Minnesota Timberwolves',
#      'nickname': 'Timberwolves',
#      'code': 'MIN',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['23', '24', '19', '24'],
#      'points': 90},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['20', '29', '35', '17'],
#      'points': 101}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12837,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-03T02:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 29,
#      'name': 'Portland Trail Blazers',
#      'nickname': 'Trail Blazers',
#      'code': 'POR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['24', '20', '30', '32', '7'],
#      'points': 113},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['21', '35', '28', '22', '12'],
#      'points': 118}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12850,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-12T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Paycom Center',
#     'city': 'Oklahoma City',
#     'state': 'OK',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 25,
#      'name': 'Oklahoma City Thunder',
#      'nickname': 'Thunder',
#      'code': 'OKC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/4/4f/Thunder_d%27Oklahoma_City_logo.svg/1200px-Thunder_d%27Oklahoma_City_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['20', '32', '23', '45'],
#      'points': 120},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '32', '45', '23'],
#      'points': 134}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12866,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-14T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 24,
#      'name': 'New York Knicks',
#      'nickname': 'Knicks',
#      'code': 'NYK',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['31', '19', '34', '29'],
#      'points': 113},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['22', '30', '37', '28'],
#      'points': 117}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12871,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-15T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Moda Center',
#     'city': 'Portland',
#     'state': 'OR',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 29,
#      'name': 'Portland Trail Blazers',
#      'nickname': 'Trail Blazers',
#      'code': 'POR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['38', '31', '34', '19'],
#      'points': 122},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['30', '24', '22', '38'],
#      'points': 114}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12890,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-17T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Golden 1 Center',
#     'city': 'Sacramento',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 30,
#      'name': 'Sacramento Kings',
#      'nickname': 'Kings',
#      'code': 'SAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['23', '27', '26', '28'],
#      'points': 104},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['35', '27', '44', '19'],
#      'points': 125}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12905,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-19T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 4,
#      'name': 'Brooklyn Nets',
#      'nickname': 'Nets',
#      'code': 'BKN',
#      'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Brooklyn_Nets_newlogo.svg/130px-Brooklyn_Nets_newlogo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '31', '23', '26'],
#      'points': 108},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '26', '34', '37'],
#      'points': 125}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12912,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-21T00:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Rocket Mortgage FieldHouse',
#     'city': 'Cleveland',
#     'state': 'OH',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 7,
#      'name': 'Cleveland Cavaliers',
#      'nickname': 'Cavaliers',
#      'code': 'CLE',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '29', '37', '23'],
#      'points': 116},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['36', '26', '30', '32'],
#      'points': 124}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12922,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-22T00:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Little Caesars Arena',
#     'city': 'Detroit',
#     'state': 'MI',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 10,
#      'name': 'Detroit Pistons',
#      'nickname': 'Pistons',
#      'code': 'DET',
#      'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '30', '26', '29'],
#      'points': 119},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '26', '30', '23'],
#      'points': 111}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12943,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-24T00:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Scotiabank Arena',
#     'city': 'Toronto',
#     'state': 'ON',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 38,
#      'name': 'Toronto Raptors',
#      'nickname': 'Raptors',
#      'code': 'TOR',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/8/89/Raptors2015.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['31', '24', '30', '41'],
#      'points': 126},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '37', '27', '21'],
#      'points': 119}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12960,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-27T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Frost Bank Center',
#     'city': 'San Antonio',
#     'state': 'TX',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 31,
#      'name': 'San Antonio Spurs',
#      'nickname': 'Spurs',
#      'code': 'SAS',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '37', '36', '30'],
#      'points': 130},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '28', '33', '25'],
#      'points': 118}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12972,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-29T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Smoothie King Center',
#     'city': 'New Orleans',
#     'state': 'LA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 23,
#      'name': 'New Orleans Pelicans',
#      'nickname': 'Pelicans',
#      'code': 'NOP',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['37', '14', '25', '29'],
#      'points': 105},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['39', '20', '22', '31'],
#      'points': 112}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 12987,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-30T22:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 20,
#      'name': 'Miami Heat',
#      'nickname': 'Heat',
#      'code': 'MIA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '25', '35', '21'],
#      'points': 109},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '27', '34', '29'],
#      'points': 117}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13005,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-01-02T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 8,
#      'name': 'Dallas Mavericks',
#      'nickname': 'Mavericks',
#      'code': 'DAL',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/b8/Mavericks_de_Dallas_logo.svg/150px-Mavericks_de_Dallas_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['26', '29', '24', '11'],
#      'points': 90},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['37', '25', '31', '34'],
#      'points': 127}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13022,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-01-04T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 10,
#      'name': 'Detroit Pistons',
#      'nickname': 'Pistons',
#      'code': 'DET',
#      'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['33', '35', '41', '29', '10'],
#      'points': 148},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['26', '40', '38', '34', '16'],
#      'points': 154}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13027,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-01-06T00:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'TD Garden',
#     'city': 'Boston',
#     'state': 'MA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 2,
#      'name': 'Boston Celtics',
#      'nickname': 'Celtics',
#      'code': 'BOS',
# ...
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 31,
#      'name': 'San Antonio Spurs',
#      'nickname': 'Spurs',
#      'code': 'SAS',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '30', '29', '30'],
#      'points': 118},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['15', '33', '31', '32'],
#      'points': 111}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13620,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-03-30T01:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 14,
#      'name': 'Houston Rockets',
#      'nickname': 'Rockets',
#      'code': 'HOU',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Houston_Rockets_logo_2003.png/330px-Houston_Rockets_logo_2003.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['13', '28', '28', '32'],
#      'points': 101},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['23', '24', '25', '28'],
#      'points': 100}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13634,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-01T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Golden 1 Center',
#     'city': 'Sacramento',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 30,
#      'name': 'Sacramento Kings',
#      'nickname': 'Kings',
#      'code': 'SAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['23', '29', '25', '29'],
#      'points': 106},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '29', '39', '32'],
#      'points': 127}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13648,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-03T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 7,
#      'name': 'Cleveland Cavaliers',
#      'nickname': 'Cavaliers',
#      'code': 'CLE',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['40', '27', '30', '32'],
#      'points': 129},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['25', '22', '34', '32'],
#      'points': 113}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13674,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-06T02:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'crypto.com Arena',
#     'city': 'Los Angeles',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['16', '26', '37', '23'],
#      'points': 102},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['41', '34', '29', '27'],
#      'points': 131}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13690,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-08T00:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Chase Center',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 11,
#      'name': 'Golden State Warriors',
#      'nickname': 'Warriors',
#      'code': 'GSW',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '26', '23', '33'],
#      'points': 110},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['41', '27', '29', '21'],
#      'points': 118}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13702,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-10T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 9,
#      'name': 'Denver Nuggets',
#      'nickname': 'Nuggets',
#      'code': 'DEN',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['34', '31', '22', '24'],
#      'points': 111},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['17', '36', '27', '15'],
#      'points': 95}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13716,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-12T01:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 14,
#      'name': 'Houston Rockets',
#      'nickname': 'Rockets',
#      'code': 'HOU',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Houston_Rockets_logo_2003.png/330px-Houston_Rockets_logo_2003.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['38', '29', '29', '25'],
#      'points': 121},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['28', '36', '34', '26'],
#      'points': 124}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13732,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-13T02:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'crypto.com Arena',
#     'city': 'Los Angeles',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '34', '25', '24'],
#      'points': 110},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['38', '22', '25', '24'],
#      'points': 109}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13746,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-04-14T19:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Chase Center',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 11,
#      'name': 'Golden State Warriors',
#      'nickname': 'Warriors',
#      'code': 'GSW',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['27', '29', '33', '27'],
#      'points': 116},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['33', '30', '32', '28'],
#      'points': 123}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13761,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-07T01:30:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'American Airlines Center',
#     'city': 'Dallas',
#     'state': 'TX',
#     'country': None},
#    'teams': {'visitors': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#     'home': {'id': 8,
#      'name': 'Dallas Mavericks',
#      'nickname': 'Mavericks',
#      'code': 'DAL',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/b8/Mavericks_de_Dallas_logo.svg/150px-Mavericks_de_Dallas_logo.svg.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['29', '22', '23', '23'],
#      'points': 97},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['40', '34', '35', '38'],
#      'points': 147}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13773,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2023-12-09T03:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 16,
#      'name': 'LA Clippers',
#      'nickname': 'Clippers',
#      'code': 'LAC',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['32', '27', '29', '29'],
#      'points': 117},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['26', '20', '29', '28'],
#      'points': 103}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None},
#   {'id': 13932,
#    'league': 'standard',
#    'season': 2023,
#    'date': {'start': '2024-02-16T02:00:00.000Z',
#     'end': None,
#     'duration': None},
#    'stage': 2,
#    'status': {'clock': None,
#     'halftime': False,
#     'short': 3,
#     'long': 'Finished'},
#    'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#    'arena': {'name': 'Delta Center',
#     'city': 'Salt Lake City',
#     'state': 'UT',
#     'country': None},
#    'teams': {'visitors': {'id': 11,
#      'name': 'Golden State Warriors',
#      'nickname': 'Warriors',
#      'code': 'GSW',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'},
#     'home': {'id': 40,
#      'name': 'Utah Jazz',
#      'nickname': 'Jazz',
#      'code': 'UTA',
#      'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#    'scores': {'visitors': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['36', '48', '36', '20'],
#      'points': 140},
#     'home': {'win': 0,
#      'loss': 0,
#      'series': {'win': 0, 'loss': 0},
#      'linescore': ['39', '32', '31', '35'],
#      'points': 137}},
#    'officials': [],
#    'timesTied': None,
#    'leadChanges': None,
#    'nugget': None}]}

# %%
# assigning json output to variable
api_response = json.loads(response.text)

# %%
# getting type of the response
type(api_response)
# Out:
# dict

# %%
# accessing response key since everything is under that
api_response['response']
# Out:
# [{'id': 12485,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-09T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 1,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 0, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Stan Sheriff Center',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['24', '19', '26', '32'],
#     'points': 101},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '23', '16', '30'],
#     'points': 96}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12495,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-11T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 1,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Climate Pledge Arena',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['21', '18', '30', '29'],
#     'points': 98},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '20', '23', '31'],
#     'points': 103}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12512,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-15T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 1,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 29,
#     'name': 'Portland Trail Blazers',
#     'nickname': 'Trail Blazers',
#     'code': 'POR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '28', '35', '36'],
#     'points': 133},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['40', '35', '36', '27'],
#     'points': 138}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12523,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-17T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 1,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 168,
#     'name': 'New Zealand Breakers',
#     'nickname': 'Breakers',
#     'code': 'BNZ',
#     'logo': ''},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['11', '32', '22', '29'],
#     'points': 94},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['31', '28', '25', '30'],
#     'points': 114}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12540,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-20T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 1,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Golden 1 Center',
#    'city': 'Sacramento',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 30,
#     'name': 'Sacramento Kings',
#     'nickname': 'Kings',
#     'code': 'SAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['26', '23', '36', '28'],
#     'points': 113},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '27', '25', '37'],
#     'points': 116}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12560,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-26T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 30,
#     'name': 'Sacramento Kings',
#     'nickname': 'Kings',
#     'code': 'SAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '40', '33', '25'],
#     'points': 130},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['24', '34', '29', '27'],
#     'points': 114}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12573,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-28T01:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '24', '29', '35'],
#     'points': 118},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['33', '30', '26', '31'],
#     'points': 120}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12582,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-29T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Footprint Center',
#    'city': 'Phoenix',
#    'state': 'AZ',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 28,
#     'name': 'Phoenix Suns',
#     'nickname': 'Suns',
#     'code': 'PHX',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '23', '28', '26'],
#     'points': 104},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['37', '29', '40', '20'],
#     'points': 126}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12598,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-10-31T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Ball Arena',
#    'city': 'Denver',
#    'state': 'CO',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 9,
#     'name': 'Denver Nuggets',
#     'nickname': 'Nuggets',
#     'code': 'DEN',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['21', '24', '24', '33'],
#     'points': 102},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['31', '27', '22', '30'],
#     'points': 110}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12613,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-02T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 19,
#     'name': 'Memphis Grizzlies',
#     'nickname': 'Grizzlies',
#     'code': 'MEM',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['19', '27', '33', '30'],
#     'points': 109},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['42', '37', '25', '29'],
#     'points': 133}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12618,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-03T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 26,
#     'name': 'Orlando Magic',
#     'nickname': 'Magic',
#     'code': 'ORL',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/b/bd/Orlando_Magic_logo_2010.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '36', '24', '25'],
#     'points': 115},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '24', '28', '27'],
#     'points': 113}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12633,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-05T00:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Target Center',
#    'city': 'Minneapolis',
#    'state': 'MN',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 22,
#     'name': 'Minnesota Timberwolves',
#     'nickname': 'Timberwolves',
#     'code': 'MIN',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '23', '27', '18'],
#     'points': 95},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '26', '37', '31'],
#     'points': 123}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12647,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-07T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'United Center',
#    'city': 'Chicago',
#    'state': 'IL',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 6,
#     'name': 'Chicago Bulls',
#     'nickname': 'Bulls',
#     'code': 'CHI',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d1/Bulls_de_Chicago_logo.svg/1200px-Bulls_de_Chicago_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '20', '26', '35'],
#     'points': 113},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['37', '29', '32', '32'],
#     'points': 130}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12653,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-09T00:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Gainbridge Fieldhouse',
#    'city': 'Indianapolis',
#    'state': 'IN',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 15,
#     'name': 'Indiana Pacers',
#     'nickname': 'Pacers',
#     'code': 'IND',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '31', '38', '20'],
#     'points': 118},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '38', '34', '33'],
#     'points': 134}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12672,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-11T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'FedExForum',
#    'city': 'Memphis',
#    'state': 'TN',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 19,
#     'name': 'Memphis Grizzlies',
#     'nickname': 'Grizzlies',
#     'code': 'MEM',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '42', '27', '24'],
#     'points': 127},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '31', '32', '26'],
#     'points': 121}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12702,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-15T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 29,
#     'name': 'Portland Trail Blazers',
#     'nickname': 'Trail Blazers',
#     'code': 'POR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '30', '28', '13'],
#     'points': 99},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['36', '31', '28', '20'],
#     'points': 115}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12724,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-18T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 28,
#     'name': 'Phoenix Suns',
#     'nickname': 'Suns',
#     'code': 'PHX',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['41', '34', '27', '29'],
#     'points': 131},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['38', '37', '24', '29'],
#     'points': 128}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12739,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-20T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 28,
#     'name': 'Phoenix Suns',
#     'nickname': 'Suns',
#     'code': 'PHX',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/5/56/Phoenix_Suns_2013.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '31', '24', '30', '12'],
#     'points': 140},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '26', '28', '31', '12'],
#     'points': 137}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12754,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-22T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'crypto.com Arena',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 17,
#     'name': 'Los Angeles Lakers',
#     'nickname': 'Lakers',
#     'code': 'LAL',
#     'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Los_Angeles_Lakers_logo.svg/220px-Los_Angeles_Lakers_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['17', '24', '34', '24'],
#     'points': 99},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '30', '40', '29'],
#     'points': 131}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12767,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-23T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Moda Center',
#    'city': 'Portland',
#    'state': 'OR',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 29,
#     'name': 'Portland Trail Blazers',
#     'nickname': 'Trail Blazers',
#     'code': 'POR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['21', '25', '27', '32'],
#     'points': 105},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '33', '24', '32'],
#     'points': 121}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12783,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-26T02:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 23,
#     'name': 'New Orleans Pelicans',
#     'nickname': 'Pelicans',
#     'code': 'NOP',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '24', '24', '23'],
#     'points': 100},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['22', '21', '25', '37'],
#     'points': 105}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12796,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-28T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 23,
#     'name': 'New Orleans Pelicans',
#     'nickname': 'Pelicans',
#     'code': 'NOP',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['24', '31', '33', '24'],
#     'points': 112},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '25', '31', '26'],
#     'points': 114}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12809,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-11-30T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'FedExForum',
#    'city': 'Memphis',
#    'state': 'TN',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 19,
#     'name': 'Memphis Grizzlies',
#     'nickname': 'Grizzlies',
#     'code': 'MEM',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['25', '17', '25', '24'],
#     'points': 91},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['24', '36', '28', '17'],
#     'points': 105}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12818,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-01T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Target Center',
#    'city': 'Minneapolis',
#    'state': 'MN',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 22,
#     'name': 'Minnesota Timberwolves',
#     'nickname': 'Timberwolves',
#     'code': 'MIN',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['23', '24', '19', '24'],
#     'points': 90},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['20', '29', '35', '17'],
#     'points': 101}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12837,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-03T02:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 29,
#     'name': 'Portland Trail Blazers',
#     'nickname': 'Trail Blazers',
#     'code': 'POR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['24', '20', '30', '32', '7'],
#     'points': 113},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['21', '35', '28', '22', '12'],
#     'points': 118}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12850,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-12T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Paycom Center',
#    'city': 'Oklahoma City',
#    'state': 'OK',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 25,
#     'name': 'Oklahoma City Thunder',
#     'nickname': 'Thunder',
#     'code': 'OKC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/4/4f/Thunder_d%27Oklahoma_City_logo.svg/1200px-Thunder_d%27Oklahoma_City_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['20', '32', '23', '45'],
#     'points': 120},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '32', '45', '23'],
#     'points': 134}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12866,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-14T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 24,
#     'name': 'New York Knicks',
#     'nickname': 'Knicks',
#     'code': 'NYK',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['31', '19', '34', '29'],
#     'points': 113},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['22', '30', '37', '28'],
#     'points': 117}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12871,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-15T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Moda Center',
#    'city': 'Portland',
#    'state': 'OR',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 29,
#     'name': 'Portland Trail Blazers',
#     'nickname': 'Trail Blazers',
#     'code': 'POR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['38', '31', '34', '19'],
#     'points': 122},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '24', '22', '38'],
#     'points': 114}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12890,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-17T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Golden 1 Center',
#    'city': 'Sacramento',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 30,
#     'name': 'Sacramento Kings',
#     'nickname': 'Kings',
#     'code': 'SAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['23', '27', '26', '28'],
#     'points': 104},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['35', '27', '44', '19'],
#     'points': 125}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12905,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-19T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 4,
#     'name': 'Brooklyn Nets',
#     'nickname': 'Nets',
#     'code': 'BKN',
#     'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Brooklyn_Nets_newlogo.svg/130px-Brooklyn_Nets_newlogo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '31', '23', '26'],
#     'points': 108},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '26', '34', '37'],
#     'points': 125}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12912,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-21T00:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Rocket Mortgage FieldHouse',
#    'city': 'Cleveland',
#    'state': 'OH',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 7,
#     'name': 'Cleveland Cavaliers',
#     'nickname': 'Cavaliers',
#     'code': 'CLE',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '29', '37', '23'],
#     'points': 116},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['36', '26', '30', '32'],
#     'points': 124}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12922,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-22T00:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Little Caesars Arena',
#    'city': 'Detroit',
#    'state': 'MI',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 10,
#     'name': 'Detroit Pistons',
#     'nickname': 'Pistons',
#     'code': 'DET',
#     'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '30', '26', '29'],
#     'points': 119},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '26', '30', '23'],
#     'points': 111}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12943,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-24T00:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Scotiabank Arena',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 38,
#     'name': 'Toronto Raptors',
#     'nickname': 'Raptors',
#     'code': 'TOR',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/8/89/Raptors2015.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['31', '24', '30', '41'],
#     'points': 126},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '37', '27', '21'],
#     'points': 119}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12960,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-27T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Frost Bank Center',
#    'city': 'San Antonio',
#    'state': 'TX',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 31,
#     'name': 'San Antonio Spurs',
#     'nickname': 'Spurs',
#     'code': 'SAS',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '37', '36', '30'],
#     'points': 130},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '28', '33', '25'],
#     'points': 118}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12972,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-29T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Smoothie King Center',
#    'city': 'New Orleans',
#    'state': 'LA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 23,
#     'name': 'New Orleans Pelicans',
#     'nickname': 'Pelicans',
#     'code': 'NOP',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['37', '14', '25', '29'],
#     'points': 105},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['39', '20', '22', '31'],
#     'points': 112}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 12987,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-30T22:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 20,
#     'name': 'Miami Heat',
#     'nickname': 'Heat',
#     'code': 'MIA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '25', '35', '21'],
#     'points': 109},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '27', '34', '29'],
#     'points': 117}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13005,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-01-02T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 8,
#     'name': 'Dallas Mavericks',
#     'nickname': 'Mavericks',
#     'code': 'DAL',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/b8/Mavericks_de_Dallas_logo.svg/150px-Mavericks_de_Dallas_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['26', '29', '24', '11'],
#     'points': 90},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['37', '25', '31', '34'],
#     'points': 127}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13022,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-01-04T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 10,
#     'name': 'Detroit Pistons',
#     'nickname': 'Pistons',
#     'code': 'DET',
#     'logo': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['33', '35', '41', '29', '10'],
#     'points': 148},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['26', '40', '38', '34', '16'],
#     'points': 154}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13027,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-01-06T00:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'TD Garden',
#    'city': 'Boston',
#    'state': 'MA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 2,
#     'name': 'Boston Celtics',
#     'nickname': 'Celtics',
#     'code': 'BOS',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/6/65/Celtics_de_Boston_logo.svg/1024px-Celtics_de_Boston_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['15', '25', '35', '22'],
#     'points': 97},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['30', '41', '36', '19'],
#     'points': 126}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13043,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-01-07T00:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Wells Fargo Center',
#    'city': 'Philadelphia',
#    'state': 'PA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 27,
#     'name': 'Philadelphia 76ers',
#     'nickname': '76ers',
#     'code': 'PHI',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/4/48/76ers_2016.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '26', '29', '33'],
#     'points': 120},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '29', '22', '30'],
#     'points': 109}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13058,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-01-09T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Fiserv Forum',
#    'city': 'Milwaukee',
#    'state': 'WI',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 21,
#     'name': 'Milwaukee Bucks',
#     'nickname': 'Bucks',
# ...
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['37', '24', '27', '27'],
#     'points': 115},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['41', '25', '22', '17'],
#     'points': 105}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13606,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-03-28T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 31,
#     'name': 'San Antonio Spurs',
#     'nickname': 'Spurs',
#     'code': 'SAS',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '30', '29', '30'],
#     'points': 118},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['15', '33', '31', '32'],
#     'points': 111}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13620,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-03-30T01:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 14,
#     'name': 'Houston Rockets',
#     'nickname': 'Rockets',
#     'code': 'HOU',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Houston_Rockets_logo_2003.png/330px-Houston_Rockets_logo_2003.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['13', '28', '28', '32'],
#     'points': 101},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['23', '24', '25', '28'],
#     'points': 100}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13634,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-01T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Golden 1 Center',
#    'city': 'Sacramento',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 30,
#     'name': 'Sacramento Kings',
#     'nickname': 'Kings',
#     'code': 'SAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['23', '29', '25', '29'],
#     'points': 106},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '29', '39', '32'],
#     'points': 127}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13648,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-03T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 7,
#     'name': 'Cleveland Cavaliers',
#     'nickname': 'Cavaliers',
#     'code': 'CLE',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['40', '27', '30', '32'],
#     'points': 129},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['25', '22', '34', '32'],
#     'points': 113}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13674,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-06T02:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'crypto.com Arena',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['16', '26', '37', '23'],
#     'points': 102},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['41', '34', '29', '27'],
#     'points': 131}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13690,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-08T00:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Chase Center',
#    'city': 'San Francisco',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 11,
#     'name': 'Golden State Warriors',
#     'nickname': 'Warriors',
#     'code': 'GSW',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '26', '23', '33'],
#     'points': 110},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['41', '27', '29', '21'],
#     'points': 118}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13702,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-10T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 9,
#     'name': 'Denver Nuggets',
#     'nickname': 'Nuggets',
#     'code': 'DEN',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['34', '31', '22', '24'],
#     'points': 111},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['17', '36', '27', '15'],
#     'points': 95}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13716,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-12T01:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 14,
#     'name': 'Houston Rockets',
#     'nickname': 'Rockets',
#     'code': 'HOU',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Houston_Rockets_logo_2003.png/330px-Houston_Rockets_logo_2003.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['38', '29', '29', '25'],
#     'points': 121},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['28', '36', '34', '26'],
#     'points': 124}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13732,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-13T02:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'crypto.com Arena',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '34', '25', '24'],
#     'points': 110},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['38', '22', '25', '24'],
#     'points': 109}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13746,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-04-14T19:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Chase Center',
#    'city': 'San Francisco',
#    'state': 'CA',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 11,
#     'name': 'Golden State Warriors',
#     'nickname': 'Warriors',
#     'code': 'GSW',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['27', '29', '33', '27'],
#     'points': 116},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['33', '30', '32', '28'],
#     'points': 123}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13761,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-07T01:30:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'American Airlines Center',
#    'city': 'Dallas',
#    'state': 'TX',
#    'country': None},
#   'teams': {'visitors': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'},
#    'home': {'id': 8,
#     'name': 'Dallas Mavericks',
#     'nickname': 'Mavericks',
#     'code': 'DAL',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/b8/Mavericks_de_Dallas_logo.svg/150px-Mavericks_de_Dallas_logo.svg.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['29', '22', '23', '23'],
#     'points': 97},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['40', '34', '35', '38'],
#     'points': 147}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13773,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2023-12-09T03:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 16,
#     'name': 'LA Clippers',
#     'nickname': 'Clippers',
#     'code': 'LAC',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['32', '27', '29', '29'],
#     'points': 117},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['26', '20', '29', '28'],
#     'points': 103}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None},
#  {'id': 13932,
#   'league': 'standard',
#   'season': 2023,
#   'date': {'start': '2024-02-16T02:00:00.000Z', 'end': None, 'duration': None},
#   'stage': 2,
#   'status': {'clock': None, 'halftime': False, 'short': 3, 'long': 'Finished'},
#   'periods': {'current': 4, 'total': 4, 'endOfPeriod': False},
#   'arena': {'name': 'Delta Center',
#    'city': 'Salt Lake City',
#    'state': 'UT',
#    'country': None},
#   'teams': {'visitors': {'id': 11,
#     'name': 'Golden State Warriors',
#     'nickname': 'Warriors',
#     'code': 'GSW',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png'},
#    'home': {'id': 40,
#     'name': 'Utah Jazz',
#     'nickname': 'Jazz',
#     'code': 'UTA',
#     'logo': 'https://upload.wikimedia.org/wikipedia/fr/3/3b/Jazz_de_l%27Utah_logo.png'}},
#   'scores': {'visitors': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['36', '48', '36', '20'],
#     'points': 140},
#    'home': {'win': 0,
#     'loss': 0,
#     'series': {'win': 0, 'loss': 0},
#     'linescore': ['39', '32', '31', '35'],
#     'points': 137}},
#   'officials': [],
#   'timesTied': None,
#   'leadChanges': None,
#   'nugget': None}]

# %%
# turning into variable
games = api_response['response']

# %%
# checking type of variable
type(games)
# Out:
# list

# %%
# Function to convert UTC to PST
def convert_to_pst(utc_time_str):
    utc_time = datetime.datetime.strptime(utc_time_str, "%Y-%m-%dT%H:%M:%S.%fZ")
    pst_time = utc_time - datetime.timedelta(hours=7)  # PST is UTC-7
    return pst_time.strftime("%Y-%m-%d %H:%M:%S")

# Creating empty dictionary
game_data = {
    'id': [],
    'date': [],
}

# Looping through games and extracting details
for game in games:
    id = game['id']
    game_data['id'].append(id)
    print('id:', id)

    date_utc = game['date']['start']
    date_pst = convert_to_pst(date_utc)
    game_data['date'].append(date_pst)

    # Print the converted date
    print('Date (PST):', date_pst)

    print('-' * 75)
# Out:
# id: 12485
# Date (PST): 2023-10-08 18:00:00
# ---------------------------------------------------------------------------
# id: 12495
# Date (PST): 2023-10-10 19:00:00
# ---------------------------------------------------------------------------
# id: 12512
# Date (PST): 2023-10-14 18:00:00
# ---------------------------------------------------------------------------
# id: 12523
# Date (PST): 2023-10-16 18:00:00
# ---------------------------------------------------------------------------
# id: 12540
# Date (PST): 2023-10-19 19:00:00
# ---------------------------------------------------------------------------
# id: 12560
# Date (PST): 2023-10-25 18:00:00
# ---------------------------------------------------------------------------
# id: 12573
# Date (PST): 2023-10-27 18:30:00
# ---------------------------------------------------------------------------
# id: 12582
# Date (PST): 2023-10-28 19:00:00
# ---------------------------------------------------------------------------
# id: 12598
# Date (PST): 2023-10-30 18:00:00
# ---------------------------------------------------------------------------
# id: 12613
# Date (PST): 2023-11-01 18:00:00
# ---------------------------------------------------------------------------
# id: 12618
# Date (PST): 2023-11-02 18:00:00
# ---------------------------------------------------------------------------
# id: 12633
# Date (PST): 2023-11-04 17:00:00
# ---------------------------------------------------------------------------
# id: 12647
# Date (PST): 2023-11-06 18:00:00
# ---------------------------------------------------------------------------
# id: 12653
# Date (PST): 2023-11-08 17:00:00
# ---------------------------------------------------------------------------
# id: 12672
# Date (PST): 2023-11-10 18:00:00
# ---------------------------------------------------------------------------
# id: 12702
# Date (PST): 2023-11-14 19:00:00
# ---------------------------------------------------------------------------
# id: 12724
# Date (PST): 2023-11-17 20:00:00
# ---------------------------------------------------------------------------
# id: 12739
# Date (PST): 2023-11-19 18:00:00
# ---------------------------------------------------------------------------
# id: 12754
# Date (PST): 2023-11-21 20:00:00
# ---------------------------------------------------------------------------
# id: 12767
# Date (PST): 2023-11-22 20:00:00
# ---------------------------------------------------------------------------
# id: 12783
# Date (PST): 2023-11-25 19:30:00
# ---------------------------------------------------------------------------
# id: 12796
# Date (PST): 2023-11-27 19:00:00
# ---------------------------------------------------------------------------
# id: 12809
# Date (PST): 2023-11-29 18:00:00
# ---------------------------------------------------------------------------
# id: 12818
# Date (PST): 2023-11-30 18:00:00
# ---------------------------------------------------------------------------
# id: 12837
# Date (PST): 2023-12-02 19:30:00
# ---------------------------------------------------------------------------
# id: 12850
# Date (PST): 2023-12-11 18:00:00
# ---------------------------------------------------------------------------
# id: 12866
# Date (PST): 2023-12-13 19:00:00
# ---------------------------------------------------------------------------
# id: 12871
# Date (PST): 2023-12-14 20:00:00
# ---------------------------------------------------------------------------
# id: 12890
# Date (PST): 2023-12-16 20:00:00
# ---------------------------------------------------------------------------
# id: 12905
# Date (PST): 2023-12-18 19:00:00
# ---------------------------------------------------------------------------
# id: 12912
# Date (PST): 2023-12-20 17:00:00
# ---------------------------------------------------------------------------
# id: 12922
# Date (PST): 2023-12-21 17:00:00
# ---------------------------------------------------------------------------
# id: 12943
# Date (PST): 2023-12-23 17:30:00
# ---------------------------------------------------------------------------
# id: 12960
# Date (PST): 2023-12-26 18:00:00
# ---------------------------------------------------------------------------
# id: 12972
# Date (PST): 2023-12-28 18:00:00
# ---------------------------------------------------------------------------
# id: 12987
# Date (PST): 2023-12-30 15:00:00
# ---------------------------------------------------------------------------
# id: 13005
# Date (PST): 2024-01-01 19:00:00
# ---------------------------------------------------------------------------
# id: 13022
# Date (PST): 2024-01-03 19:00:00
# ---------------------------------------------------------------------------
# id: 13027
# Date (PST): 2024-01-05 17:00:00
# ---------------------------------------------------------------------------
# id: 13043
# Date (PST): 2024-01-06 17:30:00
# ---------------------------------------------------------------------------
# id: 13058
# Date (PST): 2024-01-08 18:00:00
# ---------------------------------------------------------------------------
# id: 13072
# Date (PST): 2024-01-10 20:00:00
# ---------------------------------------------------------------------------
# id: 13088
# Date (PST): 2024-01-12 19:30:00
# ---------------------------------------------------------------------------
# id: 13097
# Date (PST): 2024-01-13 19:30:00
# ---------------------------------------------------------------------------
# id: 13112
# Date (PST): 2024-01-15 19:00:00
# ---------------------------------------------------------------------------
# id: 13124
# Date (PST): 2024-01-17 19:00:00
# ---------------------------------------------------------------------------
# id: 13129
# Date (PST): 2024-01-18 19:00:00
# ---------------------------------------------------------------------------
# id: 13146
# Date (PST): 2024-01-20 18:00:00
# ---------------------------------------------------------------------------
# id: 13164
# Date (PST): 2024-01-23 18:00:00
# ---------------------------------------------------------------------------
# id: 13176
# Date (PST): 2024-01-25 17:00:00
# ---------------------------------------------------------------------------
# id: 13195
# Date (PST): 2024-01-27 17:00:00
# ---------------------------------------------------------------------------
# id: 13208
# Date (PST): 2024-01-29 17:30:00
# ---------------------------------------------------------------------------
# id: 13219
# Date (PST): 2024-01-30 17:30:00
# ---------------------------------------------------------------------------
# id: 13234
# Date (PST): 2024-02-01 20:00:00
# ---------------------------------------------------------------------------
# id: 13259
# Date (PST): 2024-02-04 18:00:00
# ---------------------------------------------------------------------------
# id: 13272
# Date (PST): 2024-02-06 19:00:00
# ---------------------------------------------------------------------------
# id: 13287
# Date (PST): 2024-02-08 19:00:00
# ---------------------------------------------------------------------------
# id: 13317
# Date (PST): 2024-02-12 19:00:00
# ---------------------------------------------------------------------------
# id: 13336
# Date (PST): 2024-02-14 19:00:00
# ---------------------------------------------------------------------------
# id: 13349
# Date (PST): 2024-02-22 19:00:00
# ---------------------------------------------------------------------------
# id: 13373
# Date (PST): 2024-02-25 18:00:00
# ---------------------------------------------------------------------------
# id: 13383
# Date (PST): 2024-02-27 17:30:00
# ---------------------------------------------------------------------------
# id: 13398
# Date (PST): 2024-02-29 17:00:00
# ---------------------------------------------------------------------------
# id: 13415
# Date (PST): 2024-03-02 15:00:00
# ---------------------------------------------------------------------------
# id: 13430
# Date (PST): 2024-03-04 19:00:00
# ---------------------------------------------------------------------------
# id: 13446
# Date (PST): 2024-03-06 19:00:00
# ---------------------------------------------------------------------------
# id: 13470
# Date (PST): 2024-03-09 19:00:00
# ---------------------------------------------------------------------------
# id: 13491
# Date (PST): 2024-03-12 18:00:00
# ---------------------------------------------------------------------------
# id: 13514
# Date (PST): 2024-03-15 18:30:00
# ---------------------------------------------------------------------------
# id: 13522
# Date (PST): 2024-03-16 18:30:00
# ---------------------------------------------------------------------------
# id: 13535
# Date (PST): 2024-03-18 18:00:00
# ---------------------------------------------------------------------------
# id: 13548
# Date (PST): 2024-03-20 17:00:00
# ---------------------------------------------------------------------------
# id: 13556
# Date (PST): 2024-03-21 17:30:00
# ---------------------------------------------------------------------------
# id: 13572
# Date (PST): 2024-03-23 17:00:00
# ---------------------------------------------------------------------------
# id: 13589
# Date (PST): 2024-03-25 18:00:00
# ---------------------------------------------------------------------------
# id: 13606
# Date (PST): 2024-03-27 18:00:00
# ---------------------------------------------------------------------------
# id: 13620
# Date (PST): 2024-03-29 18:30:00
# ---------------------------------------------------------------------------
# id: 13634
# Date (PST): 2024-03-31 18:00:00
# ---------------------------------------------------------------------------
# id: 13648
# Date (PST): 2024-04-02 18:00:00
# ---------------------------------------------------------------------------
# id: 13674
# Date (PST): 2024-04-05 19:30:00
# ---------------------------------------------------------------------------
# id: 13690
# Date (PST): 2024-04-07 17:30:00
# ---------------------------------------------------------------------------
# id: 13702
# Date (PST): 2024-04-09 18:00:00
# ---------------------------------------------------------------------------
# id: 13716
# Date (PST): 2024-04-11 18:00:00
# ---------------------------------------------------------------------------
# id: 13732
# Date (PST): 2024-04-12 19:30:00
# ---------------------------------------------------------------------------
# id: 13746
# Date (PST): 2024-04-14 12:30:00
# ---------------------------------------------------------------------------
# id: 13761
# Date (PST): 2023-12-06 18:30:00
# ---------------------------------------------------------------------------
# id: 13773
# Date (PST): 2023-12-08 20:00:00
# ---------------------------------------------------------------------------
# id: 13932
# Date (PST): 2024-02-15 19:00:00
# ---------------------------------------------------------------------------

# %%
# checking that it is a dictionary
type(game_data)
# Out:
# dict

# %%
# convert the game dictionary to a df
date_df = pd.DataFrame(game_data)

# Manipulate the 'date' column to keep only the first 10 characters
date_df['date'] = date_df['date'].str[:10]

# Print the modified DataFrame
print(date_df)
# Out:
#        id        date
# 0   12485  2023-10-08
# 1   12495  2023-10-10
# 2   12512  2023-10-14
# 3   12523  2023-10-16
# 4   12540  2023-10-19
# ..    ...         ...
# 83  13732  2024-04-12
# 84  13746  2024-04-14
# 85  13761  2023-12-06
# 86  13773  2023-12-08
# 87  13932  2024-02-15
#
# [88 rows x 2 columns]

# %%
# turn into csv without index
date_df.to_csv('game_data', index=False)

# %%
# adding secret for connection password
db_password = userdata.get('RDS_PASSWORD')

# %%
# create engine to connect with database
engine = create_engine(f'mysql+mysqldb://admin:{db_password}@sql-project.ca9jkrwdnacm.us-east-1.rds.amazonaws.com/JazzData')

# %%
# transitioning the dataframe into sql
date_df.to_sql('GameDate', engine, if_exists='replace', index=False)
# Out:
# 88
